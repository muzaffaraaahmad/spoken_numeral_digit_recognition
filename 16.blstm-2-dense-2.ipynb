# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
import seaborn as sns
import librosa
from librosa import display
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.utils import plot_model
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

import random

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)
# Out:
# 2024-11-13 12:50:02.928913: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-13 12:50:03.521317: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Normalized features

# %%
# Define the path to your dataset
path = "/home/muzaffar/Desktop/Research/papers/mono-model-word-spoken/paper-001-final/1-20 data/ORIGINAL-SLOW-1-20"
dataset_path = path

# Initialize lists to hold features and labels
feature_list = []
label_list = []

# Define a function to normalize the mel-spectrogram
def normalize_mel_spectrogram(mel_spec):
    return (mel_spec - np.mean(mel_spec)) / np.std(mel_spec)

# Define the sample rate (fs)
fs = 16000  # Sample rate in Hz

# Define frame size and overlap based on sample rate (in seconds)
frame_size = int(0.025 * fs)  # 25 ms frame size
overlap = int(0.020 * fs)     # 20 ms overlap size

# Update the feature extraction process
for class_folder in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_folder)

    for file in tqdm(os.listdir(class_path)):
        if not file.endswith('.wav'):
            continue

        audio_path = os.path.join(class_path, file)
        audio, sr = librosa.load(path=audio_path, sr=None)

        # Extract the mel-spectrogram features using the frame size and overlap defined above
        mel_spec = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=frame_size, hop_length=overlap, n_mels=42)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
        normalized_mel_spec = normalize_mel_spectrogram(mel_spec_db)

        # Pad or truncate to a fixed size
        fixed_size = 32
        if normalized_mel_spec.shape[1] < fixed_size:
            # Pad with zeros
            pad_width = fixed_size - normalized_mel_spec.shape[1]
            padded_mel_spec = np.pad(normalized_mel_spec, ((0, 0), (0, pad_width)), mode='constant')
        else:
            # Truncate to fixed size
            padded_mel_spec = normalized_mel_spec[:, :fixed_size]

        feature_list.append(padded_mel_spec.T)
        label_list.append(class_folder)

# Convert to NumPy arrays
features = np.array(feature_list)
labels = np.array(label_list)

print("Feature shape:", features.shape)
print("Label shape:", labels.shape)
# Out:
# 100%|██████████| 361/361 [00:01<00:00, 338.90it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1128.10it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1236.52it/s]
# 100%|██████████| 360/360 [00:00<00:00, 1209.27it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1018.85it/s]
# 100%|██████████| 361/361 [00:00<00:00, 986.22it/s]
# 100%|██████████| 360/360 [00:00<00:00, 1188.77it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1095.88it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1144.56it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1162.22it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1188.30it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1133.98it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1164.52it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1094.31it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1176.14it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1178.18it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1196.42it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1163.64it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1121.35it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1154.83it/s]
# Feature shape: (7200, 32, 42)
# Label shape: (7200,)

# %%
features[1].shape
# Out:
# (32, 42)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM, Bidirectional, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold

# Assuming 'features' and 'labels' arrays from the previous step
# One-hot encode labels
unique_labels = np.unique(labels)
label_map = {label: idx for idx, label in enumerate(unique_labels)}
encoded_labels = np.array([label_map[label] for label in labels])
categorical_labels = to_categorical(encoded_labels)

# Define cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Variables to store all true and predicted labels for confusion matrix and classification report
all_true_labels = []
all_predicted_labels = []

# Variables to store accuracy and loss for plotting each fold
train_accuracies_folds = []
val_accuracies_folds = []
train_losses_folds = []
val_losses_folds = []

# Function to create a BLSTM model
def create_blstm_model(input_shape, num_classes):
    model = Sequential()
    model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(Bidirectional(LSTM(64)))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


# model = Sequential()
#     model.add(Bidirectional(LSTM(256, activation='relu', return_sequences=True), input_shape=(1, X_train.shape[2])))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(128, activation='relu', return_sequences=True)))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(64, activation='relu')))
#     model.add(BatchNormalization())
#     model.add(Dropout(0.3))
#     model.add(Dense(128, activation='relu'))
#     model.add(Dropout(0.3))
#     model.add(Dense(len(np.unique(y)), activation='softmax'))

# Perform 5-fold cross-validation
fold = 1
for train_index, val_index in kf.split(features):
    print(f"Training on fold {fold}...")
    fold += 1
    
    # Split data
    X_train, X_val = features[train_index], features[val_index]
    y_train, y_val = categorical_labels[train_index], categorical_labels[val_index]

    # Get input shape and number of classes
    input_shape = (X_train.shape[1], X_train.shape[2])
    num_classes = categorical_labels.shape[1]

    # Create and compile the model
    model = create_blstm_model(input_shape, num_classes)

    # Early stopping for better training
    #early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Train the model
    history = model.fit(X_train, y_train, 
              epochs=30,  # You can adjust the number of epochs
              batch_size=32, 
              validation_data=(X_val, y_val), 
              #callbacks=[early_stopping], 
              verbose=1)
    
    # Store training and validation accuracy and loss for the fold
    train_accuracies_folds.append(history.history['accuracy'])
    val_accuracies_folds.append(history.history['val_accuracy'])
    train_losses_folds.append(history.history['loss'])
    val_losses_folds.append(history.history['val_loss'])

    # Predict the labels on the validation set
    val_predictions = np.argmax(model.predict(X_val), axis=1)
    true_labels = np.argmax(y_val, axis=1)

    # Store true and predicted labels
    all_true_labels.extend(true_labels)
    all_predicted_labels.extend(val_predictions)

# Plot accuracy and loss plots
epochs = np.arange(1, len(train_accuracies_folds[0]) + 1)

plt.figure(figsize=(12, 5))

# Accuracy plot for each fold
plt.subplot(1, 2, 1)
for i, (train_acc, val_acc) in enumerate(zip(train_accuracies_folds, val_accuracies_folds)):
    plt.plot(epochs, train_acc, label=f'Train Accuracy (Fold {i+1})')
    plt.plot(epochs, val_acc, label=f'Val Accuracy (Fold {i+1})', linestyle='--')

plt.title('Accuracy Plot')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot for each fold
plt.subplot(1, 2, 2)
for i, (train_loss, val_loss) in enumerate(zip(train_losses_folds, val_losses_folds)):
    plt.plot(epochs, train_loss, label=f'Train Loss (Fold {i+1})')
    plt.plot(epochs, val_loss, label=f'Val Loss (Fold {i+1})', linestyle='--')

plt.title('Loss Plot')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 2024-11-13 12:50:11.123383: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 12:50:11.164224: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 12:50:11.164411: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 12:50:11.165472: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-
# Training on fold 1...
# L355
# 2024-11-13 12:50:11.165623: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 12:50:11.165743: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 12:50:11.221531: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 12:50:11.221680: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 12:50:11.221809: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 12:50:11.221900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10131 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0b:00.0, compute capability: 6.1
# Epoch 1/30
# 2024-11-13 12:50:14.428454: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.0800 - loss: 2.9478 - val_accuracy: 0.2861 - val_loss: 2.3817
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2326 - loss: 2.4350 - val_accuracy: 0.4701 - val_loss: 1.7398
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3951 - loss: 1.9020 - val_accuracy: 0.5493 - val_loss: 1.3995
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4922 - loss: 1.5563 - val_accuracy: 0.6299 - val_loss: 1.1302
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5645 - loss: 1.3623 - val_accuracy: 0.6382 - val_loss: 1.1165
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6109 - loss: 1.2239 - val_accuracy: 0.7090 - val_loss: 0.9395
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6377 - loss: 1.1058 - val_accuracy: 0.7250 - val_loss: 0.8860
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6607 - loss: 1.0131 - val_accuracy: 0.7382 - val_loss: 0.8265
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7223 - loss: 0.8934 - val_accuracy: 0.7632 - val_loss: 0.8009
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7245 - loss: 0.8680 - val_accuracy: 0.7653 - val_loss: 0.7548
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7465 - loss: 0.7858 - val_accuracy: 0.7736 - val_loss: 0.7593
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7450 - loss: 0.7735 - val_accuracy: 0.7792 - val_loss: 0.7324
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7683 - loss: 0.7095 - val_accuracy: 0.7819 - val_loss: 0.7080
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7935 - loss: 0.6524 - val_accuracy: 0.7889 - val_loss: 0.7339
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8019 - loss: 0.6040 - val_accuracy: 0.7931 - val_loss: 0.7172
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8157 - loss: 0.5661 - val_accuracy: 0.7924 - val_loss: 0.7219
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8221 - loss: 0.5621 - val_accuracy: 0.8090 - val_loss: 0.7261
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8326 - loss: 0.5121 - val_accuracy: 0.8104 - val_loss: 0.7304
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8231 - loss: 0.5654 - val_accuracy: 0.8229 - val_loss: 0.6696
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8417 - loss: 0.4944 - val_accuracy: 0.8208 - val_loss: 0.7180
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8378 - loss: 0.5323 - val_accuracy: 0.8347 - val_loss: 0.6754
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8577 - loss: 0.4614 - val_accuracy: 0.8264 - val_loss: 0.7190
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8755 - loss: 0.4259 - val_accuracy: 0.8354 - val_loss: 0.6734
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8547 - loss: 0.4364 - val_accuracy: 0.8271 - val_loss: 0.7274
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8744 - loss: 0.4056 - val_accuracy: 0.8361 - val_loss: 0.7585
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8820 - loss: 0.3925 - val_accuracy: 0.8382 - val_loss: 0.6960
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8929 - loss: 0.3452 - val_accuracy: 0.8493 - val_loss: 0.6847
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8892 - loss: 0.3601 - val_accuracy: 0.8403 - val_loss: 0.6739
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8929 - loss: 0.3435 - val_accuracy: 0.8340 - val_loss: 0.7239
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8944 - loss: 0.3378 - val_accuracy: 0.8521 - val_loss: 0.7013
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 2...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0740 - loss: 2.9554 - val_accuracy: 0.2917 - val_loss: 2.4463
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2560 - loss: 2.3863 - val_accuracy: 0.4812 - val_loss: 1.7248
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3915 - loss: 1.8588 - val_accuracy: 0.6049 - val_loss: 1.2915
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4911 - loss: 1.5091 - val_accuracy: 0.6639 - val_loss: 1.0926
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5949 - loss: 1.2499 - val_accuracy: 0.7007 - val_loss: 1.0243
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6427 - loss: 1.1267 - val_accuracy: 0.7208 - val_loss: 0.9228
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6628 - loss: 1.0421 - val_accuracy: 0.7319 - val_loss: 0.8758
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7098 - loss: 0.9220 - val_accuracy: 0.7604 - val_loss: 0.7933
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7212 - loss: 0.8589 - val_accuracy: 0.7660 - val_loss: 0.8037
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7460 - loss: 0.8136 - val_accuracy: 0.7854 - val_loss: 0.7272
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7687 - loss: 0.7272 - val_accuracy: 0.7785 - val_loss: 0.7430
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7863 - loss: 0.6807 - val_accuracy: 0.7951 - val_loss: 0.6971
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8010 - loss: 0.6408 - val_accuracy: 0.8062 - val_loss: 0.6998
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8192 - loss: 0.6154 - val_accuracy: 0.8049 - val_loss: 0.6606
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8139 - loss: 0.5940 - val_accuracy: 0.7951 - val_loss: 0.7020
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8194 - loss: 0.6000 - val_accuracy: 0.8181 - val_loss: 0.6416
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8344 - loss: 0.5189 - val_accuracy: 0.8271 - val_loss: 0.6357
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8451 - loss: 0.5078 - val_accuracy: 0.8354 - val_loss: 0.6398
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8563 - loss: 0.4696 - val_accuracy: 0.8486 - val_loss: 0.6279
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8642 - loss: 0.4551 - val_accuracy: 0.8444 - val_loss: 0.6232
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8764 - loss: 0.4238 - val_accuracy: 0.8479 - val_loss: 0.6194
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8728 - loss: 0.4314 - val_accuracy: 0.8444 - val_loss: 0.6191
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8843 - loss: 0.3817 - val_accuracy: 0.8278 - val_loss: 0.7078
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8730 - loss: 0.4406 - val_accuracy: 0.8458 - val_loss: 0.6654
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8845 - loss: 0.3800 - val_accuracy: 0.8486 - val_loss: 0.6240
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8889 - loss: 0.3591 - val_accuracy: 0.8493 - val_loss: 0.6115
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8889 - loss: 0.3643 - val_accuracy: 0.8417 - val_loss: 0.6580
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8923 - loss: 0.3758 - val_accuracy: 0.8618 - val_loss: 0.5986
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8952 - loss: 0.3475 - val_accuracy: 0.8514 - val_loss: 0.6414
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8907 - loss: 0.3475 - val_accuracy: 0.8590 - val_loss: 0.6297
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 3...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0721 - loss: 2.9645 - val_accuracy: 0.1778 - val_loss: 2.6463
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.1926 - loss: 2.5886 - val_accuracy: 0.4118 - val_loss: 1.9456
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3489 - loss: 1.9937 - val_accuracy: 0.5347 - val_loss: 1.4926
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4467 - loss: 1.6633 - val_accuracy: 0.5896 - val_loss: 1.2749
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5368 - loss: 1.3942 - val_accuracy: 0.6042 - val_loss: 1.1475
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5950 - loss: 1.2175 - val_accuracy: 0.6590 - val_loss: 1.0575
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6225 - loss: 1.1204 - val_accuracy: 0.7028 - val_loss: 1.0186
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6528 - loss: 1.0553 - val_accuracy: 0.7285 - val_loss: 0.9234
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6877 - loss: 0.9247 - val_accuracy: 0.7340 - val_loss: 0.8629
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7179 - loss: 0.8599 - val_accuracy: 0.7604 - val_loss: 0.8650
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7409 - loss: 0.8089 - val_accuracy: 0.7764 - val_loss: 0.8112
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7533 - loss: 0.7529 - val_accuracy: 0.7694 - val_loss: 0.7785
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7664 - loss: 0.7147 - val_accuracy: 0.7799 - val_loss: 0.7677
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8015 - loss: 0.6406 - val_accuracy: 0.7694 - val_loss: 0.8354
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8000 - loss: 0.6505 - val_accuracy: 0.7812 - val_loss: 0.7713
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8064 - loss: 0.6260 - val_accuracy: 0.7944 - val_loss: 0.7403
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8307 - loss: 0.5492 - val_accuracy: 0.7910 - val_loss: 0.8033
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8185 - loss: 0.5758 - val_accuracy: 0.7924 - val_loss: 0.7567
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8496 - loss: 0.5183 - val_accuracy: 0.8007 - val_loss: 0.7736
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8497 - loss: 0.4899 - val_accuracy: 0.8292 - val_loss: 0.6759
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8592 - loss: 0.4695 - val_accuracy: 0.8201 - val_loss: 0.6939
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8630 - loss: 0.4487 - val_accuracy: 0.8194 - val_loss: 0.7092
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8720 - loss: 0.4268 - val_accuracy: 0.8076 - val_loss: 0.7611
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8690 - loss: 0.4327 - val_accuracy: 0.8215 - val_loss: 0.7090
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8823 - loss: 0.4135 - val_accuracy: 0.8250 - val_loss: 0.7402
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8838 - loss: 0.3952 - val_accuracy: 0.8382 - val_loss: 0.6932
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8934 - loss: 0.3710 - val_accuracy: 0.8326 - val_loss: 0.7032
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8954 - loss: 0.3705 - val_accuracy: 0.8319 - val_loss: 0.7007
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8902 - loss: 0.3539 - val_accuracy: 0.8403 - val_loss: 0.7478
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9037 - loss: 0.3302 - val_accuracy: 0.8319 - val_loss: 0.7648
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 4...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.0677 - loss: 2.9740 - val_accuracy: 0.2340 - val_loss: 2.5164
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2202 - loss: 2.4869 - val_accuracy: 0.4465 - val_loss: 1.7815
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3656 - loss: 1.9620 - val_accuracy: 0.5361 - val_loss: 1.3745
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4695 - loss: 1.5999 - val_accuracy: 0.6375 - val_loss: 1.1282
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5561 - loss: 1.3557 - val_accuracy: 0.6715 - val_loss: 0.9837
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5808 - loss: 1.2451 - val_accuracy: 0.6979 - val_loss: 0.9514
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6382 - loss: 1.1022 - val_accuracy: 0.7257 - val_loss: 0.8911
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6664 - loss: 1.0116 - val_accuracy: 0.7507 - val_loss: 0.8280
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6903 - loss: 0.9207 - val_accuracy: 0.7694 - val_loss: 0.7413
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7227 - loss: 0.8425 - val_accuracy: 0.7736 - val_loss: 0.7600
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7496 - loss: 0.7897 - val_accuracy: 0.7604 - val_loss: 0.7682
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7545 - loss: 0.7608 - val_accuracy: 0.7854 - val_loss: 0.7000
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7488 - loss: 0.7719 - val_accuracy: 0.7819 - val_loss: 0.7091
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7848 - loss: 0.6828 - val_accuracy: 0.7958 - val_loss: 0.6599
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7973 - loss: 0.6447 - val_accuracy: 0.8021 - val_loss: 0.7145
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8024 - loss: 0.6198 - val_accuracy: 0.8146 - val_loss: 0.6426
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8118 - loss: 0.6072 - val_accuracy: 0.7993 - val_loss: 0.6951
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8111 - loss: 0.6143 - val_accuracy: 0.8174 - val_loss: 0.6368
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8330 - loss: 0.5268 - val_accuracy: 0.8118 - val_loss: 0.6517
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8454 - loss: 0.4997 - val_accuracy: 0.8021 - val_loss: 0.7030
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8360 - loss: 0.5104 - val_accuracy: 0.8236 - val_loss: 0.6242
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8578 - loss: 0.4523 - val_accuracy: 0.8313 - val_loss: 0.6566
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8737 - loss: 0.4260 - val_accuracy: 0.8340 - val_loss: 0.6172
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8678 - loss: 0.4269 - val_accuracy: 0.8097 - val_loss: 0.6970
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8642 - loss: 0.4438 - val_accuracy: 0.8215 - val_loss: 0.6630
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8707 - loss: 0.4361 - val_accuracy: 0.8340 - val_loss: 0.6229
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8782 - loss: 0.4032 - val_accuracy: 0.8333 - val_loss: 0.6535
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8730 - loss: 0.4169 - val_accuracy: 0.8083 - val_loss: 0.7664
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8767 - loss: 0.4007 - val_accuracy: 0.8507 - val_loss: 0.5919
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9027 - loss: 0.3135 - val_accuracy: 0.8549 - val_loss: 0.5749
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Training on fold 5...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.0638 - loss: 2.9751 - val_accuracy: 0.2382 - val_loss: 2.5901
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2102 - loss: 2.4984 - val_accuracy: 0.4715 - val_loss: 1.7877
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3973 - loss: 1.8931 - val_accuracy: 0.5319 - val_loss: 1.4182
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5124 - loss: 1.5344 - val_accuracy: 0.6271 - val_loss: 1.1256
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5740 - loss: 1.3235 - val_accuracy: 0.6812 - val_loss: 1.0014
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6244 - loss: 1.1501 - val_accuracy: 0.7083 - val_loss: 0.9532
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6484 - loss: 1.0732 - val_accuracy: 0.7021 - val_loss: 0.8838
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6952 - loss: 0.9381 - val_accuracy: 0.7090 - val_loss: 0.8898
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7171 - loss: 0.8570 - val_accuracy: 0.7389 - val_loss: 0.8365
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7420 - loss: 0.8055 - val_accuracy: 0.7847 - val_loss: 0.7125
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7682 - loss: 0.6928 - val_accuracy: 0.7479 - val_loss: 0.8292
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7664 - loss: 0.7247 - val_accuracy: 0.7688 - val_loss: 0.7381
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8055 - loss: 0.6207 - val_accuracy: 0.7979 - val_loss: 0.6954
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8082 - loss: 0.6065 - val_accuracy: 0.8146 - val_loss: 0.6182
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8156 - loss: 0.5900 - val_accuracy: 0.8181 - val_loss: 0.6327
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8362 - loss: 0.5155 - val_accuracy: 0.7937 - val_loss: 0.7197
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8285 - loss: 0.5515 - val_accuracy: 0.8250 - val_loss: 0.6433
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8486 - loss: 0.4898 - val_accuracy: 0.8056 - val_loss: 0.6774
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8428 - loss: 0.5113 - val_accuracy: 0.8354 - val_loss: 0.6068
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8691 - loss: 0.4165 - val_accuracy: 0.8111 - val_loss: 0.7075
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8621 - loss: 0.4635 - val_accuracy: 0.8340 - val_loss: 0.5975
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8753 - loss: 0.4121 - val_accuracy: 0.8319 - val_loss: 0.6181
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8832 - loss: 0.3955 - val_accuracy: 0.8347 - val_loss: 0.6458
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8833 - loss: 0.3918 - val_accuracy: 0.8486 - val_loss: 0.6229
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8895 - loss: 0.3664 - val_accuracy: 0.8382 - val_loss: 0.6643
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8842 - loss: 0.3819 - val_accuracy: 0.8354 - val_loss: 0.7025
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8941 - loss: 0.3695 - val_accuracy: 0.8562 - val_loss: 0.5882
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9055 - loss: 0.2984 - val_accuracy: 0.8236 - val_loss: 0.7218
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8942 - loss: 0.3800 - val_accuracy: 0.8535 - val_loss: 0.6060
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8988 - loss: 0.3260 - val_accuracy: 0.8625 - val_loss: 0.6100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Calculate overall accuracy
accuracy = accuracy_score(all_true_labels, all_predicted_labels)
print(f"Overall Accuracy: {accuracy * 100:.2f}%")

# Generate classification report
class_report = classification_report(all_true_labels, all_predicted_labels, target_names=unique_labels,  digits =4)
print("Classification Report:\n", class_report)

# Generate the confusion matrix
conf_matrix = confusion_matrix(all_true_labels, all_predicted_labels)

# Normalize the confusion matrix by row (true labels)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix as heatmap with annotated percentages
plt.figure(figsize=(15, 10))
plt.imshow(conf_matrix_normalized, cmap='viridis', interpolation='nearest')

# Choose appropriate text color based on background color
threshold = conf_matrix_normalized.max() / 2.

for i in range(conf_matrix_normalized.shape[0]):
    for j in range(conf_matrix_normalized.shape[1]):
        color = "white" if conf_matrix_normalized[i, j] < threshold else "black"
        plt.text(j, i, format(conf_matrix_normalized[i, j], '.2f'), horizontalalignment="center", color=color)

# Custom ticks for confusion matrix
custom_ticks = ['Akh', 'Zi', 'Thre', 'Tsor', 'Paanch', "Sheh", "Sath", "Aeth", "Nav", "Dah",
                "Kah", "Bah", "Truwah", "Czhodah", "Pandah", "Shurah", "Sadah", "Ardah", "Kunvuh", "Vuh"]
plt.xticks(np.arange(20), custom_ticks, rotation=45)
plt.yticks(np.arange(20), custom_ticks)

plt.colorbar()
plt.title('Confusion Matrix (Normalized)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()




plt.tight_layout()
plt.show()
# Out:
# Overall Accuracy: 85.21%
# Classification Report:
#                precision    recall  f1-score   support
#
#         Aeth     0.7867    0.7583    0.7723       360
#          Akh     0.8140    0.8750    0.8434       360
#        Ardah     0.8508    0.8556    0.8532       360
#          Bah     0.8665    0.8472    0.8567       360
#      Czhodah     0.7978    0.8111    0.8044       360
#          Dah     0.8031    0.8500    0.8259       360
#          Kah     0.8333    0.8611    0.8470       360
#       Kunvuh     0.8699    0.8917    0.8807       360
#          Nav     0.9154    0.8417    0.8770       360
#       Paanch     0.8080    0.8417    0.8245       360
#       Pandah     0.8320    0.8944    0.8621       360
#        Sadah     0.8602    0.7694    0.8123       360
#         Sath     0.8381    0.8917    0.8641       360
#         Sheh     0.8457    0.8833    0.8641       360
#       Shurah     0.8832    0.8611    0.8720       360
#         Thre     0.8898    0.8750    0.8824       360
#       Truwah     0.8544    0.8806    0.8673       360
#         Tsor     0.8836    0.8222    0.8518       360
#          Vuh     0.9094    0.8639    0.8860       360
#           Zi     0.9258    0.8667    0.8953       360
#
#     accuracy                         0.8521      7200
#    macro avg     0.8534    0.8521    0.8521      7200
# weighted avg     0.8534    0.8521    0.8521      7200
