# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
import seaborn as sns
import librosa
from librosa import display
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.utils import plot_model
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

import random

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)
# Out:
# 2024-11-13 13:03:27.871950: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-13 13:03:28.475195: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Normalized features

# %%
# Define the path to your dataset
path = "/home/muzaffar/Desktop/Research/papers/mono-model-word-spoken/paper-001-final/1-20 data/ORIGINAL-SLOW-1-20"
dataset_path = path

# Initialize lists to hold features and labels
feature_list = []
label_list = []

# Define a function to normalize the mel-spectrogram
def normalize_mel_spectrogram(mel_spec):
    return (mel_spec - np.mean(mel_spec)) / np.std(mel_spec)

# Define the sample rate (fs)
fs = 16000  # Sample rate in Hz

# Define frame size and overlap based on sample rate (in seconds)
frame_size = int(0.025 * fs)  # 25 ms frame size
overlap = int(0.020 * fs)     # 20 ms overlap size

# Update the feature extraction process
for class_folder in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_folder)

    for file in tqdm(os.listdir(class_path)):
        if not file.endswith('.wav'):
            continue

        audio_path = os.path.join(class_path, file)
        audio, sr = librosa.load(path=audio_path, sr=None)

        # Extract the mel-spectrogram features using the frame size and overlap defined above
        mel_spec = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=frame_size, hop_length=overlap, n_mels=42)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
        normalized_mel_spec = normalize_mel_spectrogram(mel_spec_db)

        # Pad or truncate to a fixed size
        fixed_size = 32
        if normalized_mel_spec.shape[1] < fixed_size:
            # Pad with zeros
            pad_width = fixed_size - normalized_mel_spec.shape[1]
            padded_mel_spec = np.pad(normalized_mel_spec, ((0, 0), (0, pad_width)), mode='constant')
        else:
            # Truncate to fixed size
            padded_mel_spec = normalized_mel_spec[:, :fixed_size]

        feature_list.append(padded_mel_spec.T)
        label_list.append(class_folder)

# Convert to NumPy arrays
features = np.array(feature_list)
labels = np.array(label_list)

print("Feature shape:", features.shape)
print("Label shape:", labels.shape)
# Out:
# 100%|██████████| 361/361 [00:01<00:00, 332.42it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1037.75it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1234.76it/s]
# 100%|██████████| 360/360 [00:00<00:00, 1239.16it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1187.32it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1167.47it/s]
# 100%|██████████| 360/360 [00:00<00:00, 1200.10it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1107.49it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1119.09it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1233.75it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1216.70it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1136.72it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1101.49it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1290.00it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1219.98it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1162.10it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1118.89it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1111.26it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1137.63it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1110.57it/s]
# Feature shape: (7200, 32, 42)
# Label shape: (7200,)

# %%
features[1].shape
# Out:
# (32, 42)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM, Bidirectional, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold

# Assuming 'features' and 'labels' arrays from the previous step
# One-hot encode labels
unique_labels = np.unique(labels)
label_map = {label: idx for idx, label in enumerate(unique_labels)}
encoded_labels = np.array([label_map[label] for label in labels])
categorical_labels = to_categorical(encoded_labels)

# Define cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Variables to store all true and predicted labels for confusion matrix and classification report
all_true_labels = []
all_predicted_labels = []

# Variables to store accuracy and loss for plotting each fold
train_accuracies_folds = []
val_accuracies_folds = []
train_losses_folds = []
val_losses_folds = []

# Function to create a BLSTM model
def create_blstm_model(input_shape, num_classes):
    model = Sequential()
    model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(Bidirectional(LSTM(64, return_sequences=True)))
    model.add(Dropout(0.3))
    model.add(Bidirectional(LSTM(64)))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


# model = Sequential()
#     model.add(Bidirectional(LSTM(256, activation='relu', return_sequences=True), input_shape=(1, X_train.shape[2])))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(128, activation='relu', return_sequences=True)))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(64, activation='relu')))
#     model.add(BatchNormalization())
#     model.add(Dropout(0.3))
#     model.add(Dense(128, activation='relu'))
#     model.add(Dropout(0.3))
#     model.add(Dense(len(np.unique(y)), activation='softmax'))

# Perform 5-fold cross-validation
fold = 1
for train_index, val_index in kf.split(features):
    print(f"Training on fold {fold}...")
    fold += 1
    
    # Split data
    X_train, X_val = features[train_index], features[val_index]
    y_train, y_val = categorical_labels[train_index], categorical_labels[val_index]

    # Get input shape and number of classes
    input_shape = (X_train.shape[1], X_train.shape[2])
    num_classes = categorical_labels.shape[1]

    # Create and compile the model
    model = create_blstm_model(input_shape, num_classes)

    # Early stopping for better training
    #early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Train the model
    history = model.fit(X_train, y_train, 
              epochs=30,  # You can adjust the number of epochs
              batch_size=32, 
              validation_data=(X_val, y_val), 
              #callbacks=[early_stopping], 
              verbose=1)
    
    # Store training and validation accuracy and loss for the fold
    train_accuracies_folds.append(history.history['accuracy'])
    val_accuracies_folds.append(history.history['val_accuracy'])
    train_losses_folds.append(history.history['loss'])
    val_losses_folds.append(history.history['val_loss'])

    # Predict the labels on the validation set
    val_predictions = np.argmax(model.predict(X_val), axis=1)
    true_labels = np.argmax(y_val, axis=1)

    # Store true and predicted labels
    all_true_labels.extend(true_labels)
    all_predicted_labels.extend(val_predictions)

# Plot accuracy and loss plots
epochs = np.arange(1, len(train_accuracies_folds[0]) + 1)

plt.figure(figsize=(12, 5))

# Accuracy plot for each fold
plt.subplot(1, 2, 1)
for i, (train_acc, val_acc) in enumerate(zip(train_accuracies_folds, val_accuracies_folds)):
    plt.plot(epochs, train_acc, label=f'Train Accuracy (Fold {i+1})')
    plt.plot(epochs, val_acc, label=f'Val Accuracy (Fold {i+1})', linestyle='--')

plt.title('Accuracy Plot')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot for each fold
plt.subplot(1, 2, 2)
for i, (train_loss, val_loss) in enumerate(zip(train_losses_folds, val_losses_folds)):
    plt.plot(epochs, train_loss, label=f'Train Loss (Fold {i+1})')
    plt.plot(epochs, val_loss, label=f'Val Loss (Fold {i+1})', linestyle='--')

plt.title('Loss Plot')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 2024-11-13 13:03:36.002137: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 13:03:36.040432: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 13:03:36.040673: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 13:03:36.041980: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-
# Training on fold 1...
# L355
# 2024-11-13 13:03:36.042142: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 13:03:36.042270: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 13:03:36.109166: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 13:03:36.109331: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 13:03:36.109466: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 13:03:36.109556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10138 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0b:00.0, compute capability: 6.1
# Epoch 1/30
# 2024-11-13 13:03:40.196801: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.1304 - loss: 2.8161 - val_accuracy: 0.4187 - val_loss: 1.8874
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4357 - loss: 1.8265 - val_accuracy: 0.5896 - val_loss: 1.2405
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5823 - loss: 1.3037 - val_accuracy: 0.6757 - val_loss: 1.0308
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6603 - loss: 1.1013 - val_accuracy: 0.7264 - val_loss: 0.8641
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7360 - loss: 0.8891 - val_accuracy: 0.7507 - val_loss: 0.8092
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7624 - loss: 0.7705 - val_accuracy: 0.7694 - val_loss: 0.7938
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7798 - loss: 0.7397 - val_accuracy: 0.7701 - val_loss: 0.7684
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8033 - loss: 0.6410 - val_accuracy: 0.7965 - val_loss: 0.6663
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8315 - loss: 0.5616 - val_accuracy: 0.8042 - val_loss: 0.6904
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8313 - loss: 0.5520 - val_accuracy: 0.7944 - val_loss: 0.7028
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8711 - loss: 0.4539 - val_accuracy: 0.7924 - val_loss: 0.7329
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8680 - loss: 0.4537 - val_accuracy: 0.8076 - val_loss: 0.7126
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8565 - loss: 0.4597 - val_accuracy: 0.8368 - val_loss: 0.6087
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8839 - loss: 0.3798 - val_accuracy: 0.8313 - val_loss: 0.6138
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9008 - loss: 0.3337 - val_accuracy: 0.8229 - val_loss: 0.6323
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8929 - loss: 0.3584 - val_accuracy: 0.8264 - val_loss: 0.6211
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8957 - loss: 0.3357 - val_accuracy: 0.8410 - val_loss: 0.6337
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8980 - loss: 0.3409 - val_accuracy: 0.8438 - val_loss: 0.6166
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9226 - loss: 0.2663 - val_accuracy: 0.8451 - val_loss: 0.5917
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9137 - loss: 0.2899 - val_accuracy: 0.8465 - val_loss: 0.5944
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9201 - loss: 0.2652 - val_accuracy: 0.8194 - val_loss: 0.7272
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9098 - loss: 0.3132 - val_accuracy: 0.8417 - val_loss: 0.6315
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9239 - loss: 0.2437 - val_accuracy: 0.8326 - val_loss: 0.6434
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9297 - loss: 0.2283 - val_accuracy: 0.8597 - val_loss: 0.5909
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9410 - loss: 0.1947 - val_accuracy: 0.8417 - val_loss: 0.6594
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9275 - loss: 0.2366 - val_accuracy: 0.8472 - val_loss: 0.6595
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9300 - loss: 0.2201 - val_accuracy: 0.8368 - val_loss: 0.6638
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9225 - loss: 0.2514 - val_accuracy: 0.8514 - val_loss: 0.6564
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9444 - loss: 0.1835 - val_accuracy: 0.8451 - val_loss: 0.6858
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9389 - loss: 0.2000 - val_accuracy: 0.8549 - val_loss: 0.6585
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Training on fold 2...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.1413 - loss: 2.7838 - val_accuracy: 0.4097 - val_loss: 1.8050
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4226 - loss: 1.7693 - val_accuracy: 0.5938 - val_loss: 1.2667
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5843 - loss: 1.3204 - val_accuracy: 0.6757 - val_loss: 1.0022
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6724 - loss: 1.0332 - val_accuracy: 0.7222 - val_loss: 0.9126
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7291 - loss: 0.8808 - val_accuracy: 0.7535 - val_loss: 0.8083
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7588 - loss: 0.7841 - val_accuracy: 0.7757 - val_loss: 0.7614
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7714 - loss: 0.7246 - val_accuracy: 0.7826 - val_loss: 0.7149
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7970 - loss: 0.6361 - val_accuracy: 0.8028 - val_loss: 0.6454
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8344 - loss: 0.5374 - val_accuracy: 0.7993 - val_loss: 0.6342
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8384 - loss: 0.5090 - val_accuracy: 0.8111 - val_loss: 0.6327
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8567 - loss: 0.4705 - val_accuracy: 0.8292 - val_loss: 0.5720
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8632 - loss: 0.4625 - val_accuracy: 0.8333 - val_loss: 0.5904
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8756 - loss: 0.3877 - val_accuracy: 0.8271 - val_loss: 0.6122
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8818 - loss: 0.3876 - val_accuracy: 0.8347 - val_loss: 0.6234
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9012 - loss: 0.3152 - val_accuracy: 0.8222 - val_loss: 0.6483
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8879 - loss: 0.3474 - val_accuracy: 0.8104 - val_loss: 0.7280
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8722 - loss: 0.4186 - val_accuracy: 0.8451 - val_loss: 0.5346
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9087 - loss: 0.3096 - val_accuracy: 0.8458 - val_loss: 0.5501
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9167 - loss: 0.2702 - val_accuracy: 0.8438 - val_loss: 0.5965
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9264 - loss: 0.2420 - val_accuracy: 0.8417 - val_loss: 0.6626
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9163 - loss: 0.2702 - val_accuracy: 0.8479 - val_loss: 0.6432
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9290 - loss: 0.2253 - val_accuracy: 0.8597 - val_loss: 0.5312
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9420 - loss: 0.1918 - val_accuracy: 0.8535 - val_loss: 0.5609
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9253 - loss: 0.2316 - val_accuracy: 0.8417 - val_loss: 0.5982
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9304 - loss: 0.2252 - val_accuracy: 0.8535 - val_loss: 0.6242
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9277 - loss: 0.2378 - val_accuracy: 0.8417 - val_loss: 0.6807
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9222 - loss: 0.2416 - val_accuracy: 0.8708 - val_loss: 0.5677
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9529 - loss: 0.1556 - val_accuracy: 0.8792 - val_loss: 0.5506
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9498 - loss: 0.1576 - val_accuracy: 0.8556 - val_loss: 0.6365
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9512 - loss: 0.1556 - val_accuracy: 0.8562 - val_loss: 0.6948
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Training on fold 3...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.1153 - loss: 2.8397 - val_accuracy: 0.3694 - val_loss: 1.9225
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4034 - loss: 1.8294 - val_accuracy: 0.5646 - val_loss: 1.3353
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5748 - loss: 1.3250 - val_accuracy: 0.6493 - val_loss: 1.1242
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6451 - loss: 1.0815 - val_accuracy: 0.7056 - val_loss: 0.9149
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7138 - loss: 0.8984 - val_accuracy: 0.7194 - val_loss: 0.8743
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7608 - loss: 0.7610 - val_accuracy: 0.7479 - val_loss: 0.7594
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7651 - loss: 0.7131 - val_accuracy: 0.7535 - val_loss: 0.8174
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7983 - loss: 0.6397 - val_accuracy: 0.7847 - val_loss: 0.7244
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8234 - loss: 0.5746 - val_accuracy: 0.7903 - val_loss: 0.7131
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8537 - loss: 0.4797 - val_accuracy: 0.8007 - val_loss: 0.6417
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8519 - loss: 0.4684 - val_accuracy: 0.8188 - val_loss: 0.6525
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8711 - loss: 0.4132 - val_accuracy: 0.7847 - val_loss: 0.6790
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8628 - loss: 0.4523 - val_accuracy: 0.8062 - val_loss: 0.6416
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8913 - loss: 0.3684 - val_accuracy: 0.8292 - val_loss: 0.6286
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9047 - loss: 0.3251 - val_accuracy: 0.8278 - val_loss: 0.6106
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8879 - loss: 0.3668 - val_accuracy: 0.8361 - val_loss: 0.5948
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9075 - loss: 0.2945 - val_accuracy: 0.8201 - val_loss: 0.6270
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9026 - loss: 0.3181 - val_accuracy: 0.8201 - val_loss: 0.6654
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9089 - loss: 0.2773 - val_accuracy: 0.8444 - val_loss: 0.6104
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9184 - loss: 0.2563 - val_accuracy: 0.8479 - val_loss: 0.5827
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9260 - loss: 0.2432 - val_accuracy: 0.8271 - val_loss: 0.6654
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9278 - loss: 0.2426 - val_accuracy: 0.8472 - val_loss: 0.6284
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9291 - loss: 0.2329 - val_accuracy: 0.8368 - val_loss: 0.6530
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9354 - loss: 0.2075 - val_accuracy: 0.8354 - val_loss: 0.7071
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9253 - loss: 0.2562 - val_accuracy: 0.8486 - val_loss: 0.6345
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9397 - loss: 0.1996 - val_accuracy: 0.8340 - val_loss: 0.6742
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9291 - loss: 0.2131 - val_accuracy: 0.8424 - val_loss: 0.6315
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9413 - loss: 0.1925 - val_accuracy: 0.8618 - val_loss: 0.6239
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9416 - loss: 0.1876 - val_accuracy: 0.8535 - val_loss: 0.6790
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9469 - loss: 0.1739 - val_accuracy: 0.8271 - val_loss: 0.7756
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Training on fold 4...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.1294 - loss: 2.7726 - val_accuracy: 0.3965 - val_loss: 1.7943
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4424 - loss: 1.7361 - val_accuracy: 0.6201 - val_loss: 1.2168
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5847 - loss: 1.2761 - val_accuracy: 0.6590 - val_loss: 1.0758
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6494 - loss: 1.0884 - val_accuracy: 0.7118 - val_loss: 0.9383
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7065 - loss: 0.8954 - val_accuracy: 0.7257 - val_loss: 0.9276
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7456 - loss: 0.8215 - val_accuracy: 0.7771 - val_loss: 0.7189
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7706 - loss: 0.7158 - val_accuracy: 0.7812 - val_loss: 0.6925
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8110 - loss: 0.6293 - val_accuracy: 0.7965 - val_loss: 0.6692
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8299 - loss: 0.5602 - val_accuracy: 0.8062 - val_loss: 0.6042
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8495 - loss: 0.5078 - val_accuracy: 0.8201 - val_loss: 0.6027
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8528 - loss: 0.4915 - val_accuracy: 0.8139 - val_loss: 0.6376
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8595 - loss: 0.4901 - val_accuracy: 0.8278 - val_loss: 0.5646
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8729 - loss: 0.4228 - val_accuracy: 0.7979 - val_loss: 0.6955
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8815 - loss: 0.3816 - val_accuracy: 0.8188 - val_loss: 0.6415
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8715 - loss: 0.4273 - val_accuracy: 0.8160 - val_loss: 0.6583
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8835 - loss: 0.3889 - val_accuracy: 0.8472 - val_loss: 0.5459
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8978 - loss: 0.3217 - val_accuracy: 0.8479 - val_loss: 0.5450
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9079 - loss: 0.3020 - val_accuracy: 0.8285 - val_loss: 0.6039
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9039 - loss: 0.3220 - val_accuracy: 0.8583 - val_loss: 0.5577
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9111 - loss: 0.2952 - val_accuracy: 0.8493 - val_loss: 0.6046
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8981 - loss: 0.3239 - val_accuracy: 0.8368 - val_loss: 0.6108
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9230 - loss: 0.2596 - val_accuracy: 0.8521 - val_loss: 0.5712
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9251 - loss: 0.2471 - val_accuracy: 0.8528 - val_loss: 0.5978
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9232 - loss: 0.2355 - val_accuracy: 0.8465 - val_loss: 0.6097
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9372 - loss: 0.2112 - val_accuracy: 0.8403 - val_loss: 0.6398
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9336 - loss: 0.2266 - val_accuracy: 0.8694 - val_loss: 0.5466
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9465 - loss: 0.1928 - val_accuracy: 0.8194 - val_loss: 0.7902
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9222 - loss: 0.2715 - val_accuracy: 0.8694 - val_loss: 0.5225
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9461 - loss: 0.1818 - val_accuracy: 0.8694 - val_loss: 0.5174
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9488 - loss: 0.1704 - val_accuracy: 0.8403 - val_loss: 0.6799
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Training on fold 5...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.1364 - loss: 2.8070 - val_accuracy: 0.4083 - val_loss: 1.9109
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4251 - loss: 1.7999 - val_accuracy: 0.5479 - val_loss: 1.3482
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5763 - loss: 1.3166 - val_accuracy: 0.6618 - val_loss: 1.0700
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6381 - loss: 1.0981 - val_accuracy: 0.7069 - val_loss: 0.9272
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7200 - loss: 0.8840 - val_accuracy: 0.7354 - val_loss: 0.8629
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7670 - loss: 0.7654 - val_accuracy: 0.7576 - val_loss: 0.7684
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7797 - loss: 0.6858 - val_accuracy: 0.7590 - val_loss: 0.7849
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8102 - loss: 0.6154 - val_accuracy: 0.7757 - val_loss: 0.7319
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8211 - loss: 0.5840 - val_accuracy: 0.8194 - val_loss: 0.6407
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8322 - loss: 0.5356 - val_accuracy: 0.8139 - val_loss: 0.6493
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8584 - loss: 0.4656 - val_accuracy: 0.8021 - val_loss: 0.6889
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8586 - loss: 0.4697 - val_accuracy: 0.8236 - val_loss: 0.6395
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8891 - loss: 0.3753 - val_accuracy: 0.8264 - val_loss: 0.6291
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8854 - loss: 0.3817 - val_accuracy: 0.8215 - val_loss: 0.6477
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8933 - loss: 0.3352 - val_accuracy: 0.8188 - val_loss: 0.6426
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9021 - loss: 0.3374 - val_accuracy: 0.8257 - val_loss: 0.6686
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8992 - loss: 0.3199 - val_accuracy: 0.8292 - val_loss: 0.6542
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9118 - loss: 0.2961 - val_accuracy: 0.8368 - val_loss: 0.6230
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9157 - loss: 0.2785 - val_accuracy: 0.8243 - val_loss: 0.6932
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9176 - loss: 0.2680 - val_accuracy: 0.8410 - val_loss: 0.6472
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9206 - loss: 0.2551 - val_accuracy: 0.8264 - val_loss: 0.6746
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9075 - loss: 0.3073 - val_accuracy: 0.8333 - val_loss: 0.6923
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9243 - loss: 0.2480 - val_accuracy: 0.8229 - val_loss: 0.7076
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9238 - loss: 0.2489 - val_accuracy: 0.8347 - val_loss: 0.6683
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9330 - loss: 0.2083 - val_accuracy: 0.8535 - val_loss: 0.5606
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9321 - loss: 0.2162 - val_accuracy: 0.8507 - val_loss: 0.6026
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9431 - loss: 0.1866 - val_accuracy: 0.8507 - val_loss: 0.6225
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9343 - loss: 0.2224 - val_accuracy: 0.8396 - val_loss: 0.6878
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9418 - loss: 0.1985 - val_accuracy: 0.8493 - val_loss: 0.6336
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9389 - loss: 0.1966 - val_accuracy: 0.8597 - val_loss: 0.5941
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Calculate overall accuracy
accuracy = accuracy_score(all_true_labels, all_predicted_labels)
print(f"Overall Accuracy: {accuracy * 100:.2f}%")

# Generate classification report
class_report = classification_report(all_true_labels, all_predicted_labels, target_names=unique_labels,  digits =4)
print("Classification Report:\n", class_report)

# Generate the confusion matrix
conf_matrix = confusion_matrix(all_true_labels, all_predicted_labels)

# Normalize the confusion matrix by row (true labels)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix as heatmap with annotated percentages
plt.figure(figsize=(15, 10))
plt.imshow(conf_matrix_normalized, cmap='viridis', interpolation='nearest')

# Choose appropriate text color based on background color
threshold = conf_matrix_normalized.max() / 2.

for i in range(conf_matrix_normalized.shape[0]):
    for j in range(conf_matrix_normalized.shape[1]):
        color = "white" if conf_matrix_normalized[i, j] < threshold else "black"
        plt.text(j, i, format(conf_matrix_normalized[i, j], '.2f'), horizontalalignment="center", color=color)

# Custom ticks for confusion matrix
custom_ticks = ['Akh', 'Zi', 'Thre', 'Tsor', 'Paanch', "Sheh", "Sath", "Aeth", "Nav", "Dah",
                "Kah", "Bah", "Truwah", "Czhodah", "Pandah", "Shurah", "Sadah", "Ardah", "Kunvuh", "Vuh"]
plt.xticks(np.arange(20), custom_ticks, rotation=45)
plt.yticks(np.arange(20), custom_ticks)

plt.colorbar()
plt.title('Confusion Matrix (Normalized)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()




plt.tight_layout()
plt.show()
# Out:
# Overall Accuracy: 84.76%
# Classification Report:
#                precision    recall  f1-score   support
#
#         Aeth     0.8418    0.7833    0.8115       360
#          Akh     0.7939    0.8667    0.8287       360
#        Ardah     0.8622    0.8861    0.8740       360
#          Bah     0.8466    0.8278    0.8371       360
#      Czhodah     0.8599    0.7500    0.8012       360
#          Dah     0.7733    0.8528    0.8111       360
#          Kah     0.8408    0.8361    0.8384       360
#       Kunvuh     0.8631    0.8583    0.8607       360
#          Nav     0.8524    0.8500    0.8512       360
#       Paanch     0.8225    0.8111    0.8168       360
#       Pandah     0.8506    0.8222    0.8362       360
#        Sadah     0.7922    0.8472    0.8188       360
#         Sath     0.8391    0.8833    0.8606       360
#         Sheh     0.8364    0.8806    0.8579       360
#       Shurah     0.9000    0.8500    0.8743       360
#         Thre     0.9009    0.8583    0.8791       360
#       Truwah     0.8840    0.8889    0.8864       360
#         Tsor     0.8643    0.8667    0.8655       360
#          Vuh     0.8522    0.8806    0.8661       360
#           Zi     0.9029    0.8528    0.8771       360
#
#     accuracy                         0.8476      7200
#    macro avg     0.8489    0.8476    0.8476      7200
# weighted avg     0.8489    0.8476    0.8476      7200
