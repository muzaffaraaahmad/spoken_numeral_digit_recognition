# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
import seaborn as sns
import librosa
from librosa import display
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.utils import plot_model
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

import random

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)
# Out:
# 2024-11-13 10:39:19.827149: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-13 10:39:20.405434: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Normalized features

# %%
import os
import numpy as np
import librosa
from tqdm import tqdm

# Define the path to your dataset
path = "/home/muzaffar/Desktop/Research/papers/mono-model-word-spoken/paper-001-final/1-20 data/ORIGINAL-SLOW-1-20"
dataset_path = path
# Initialize lists to hold features and labels
feature_list = []
label_list = []

# Define a function to normalize spectrograms
def normalize_spectrogram(spec):
    return (spec - np.mean(spec)) / np.std(spec)

# Define the sample rate (fs)
fs = 16000  # Sample rate in Hz

# Define frame size and overlap based on sample rate (in seconds)
frame_size = int(0.025 * fs)  # 25 ms frame size
overlap = int(0.020 * fs)     # 20 ms overlap size

# Update the feature extraction process
for class_folder in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_folder)

    for file in tqdm(os.listdir(class_path)):
        if not file.endswith('.wav'):
            continue

        audio_path = os.path.join(class_path, file)
        audio, sr = librosa.load(path=audio_path, sr=None)

        # Extract the spectrogram using the frame size and overlap defined above
        S = librosa.stft(y=audio, n_fft=frame_size, hop_length=overlap)
        spectrogram = np.abs(S)
        normalized_spectrogram = normalize_spectrogram(spectrogram)

        # Pad or truncate to fixed size
        fixed_size = 32
        if normalized_spectrogram.shape[1] < fixed_size:
            # Pad with zeros
            pad_width = fixed_size - normalized_spectrogram.shape[1]
            padded_spectrogram = np.pad(normalized_spectrogram, ((0, 0), (0, pad_width)), mode='constant')
        else:
            # Truncate to fixed size
            padded_spectrogram = normalized_spectrogram[:, :fixed_size]

        feature_list.append(padded_spectrogram.T)
        label_list.append(class_folder)

# Convert to NumPy arrays
features = np.array(feature_list)
labels = np.array(label_list)

print("Feature shape:", features.shape)
print("Label shape:", labels.shape)
# Out:
# 100%|██████████| 361/361 [00:00<00:00, 402.41it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2411.36it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2498.03it/s]
# 100%|██████████| 360/360 [00:00<00:00, 2509.06it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2543.47it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2484.98it/s]
# 100%|██████████| 360/360 [00:00<00:00, 2519.27it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2544.93it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2486.31it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2445.20it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2463.77it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2375.39it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2520.44it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2578.96it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2485.81it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2544.69it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2592.18it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2499.28it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2505.83it/s]
# 100%|██████████| 361/361 [00:00<00:00, 2529.81it/s]
# Feature shape: (7200, 32, 201)
# Label shape: (7200,)

# %%
features[1].shape
# Out:
# (32, 201)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM, Bidirectional, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold

# Assuming 'features' and 'labels' arrays from the previous step
# One-hot encode labels
unique_labels = np.unique(labels)
label_map = {label: idx for idx, label in enumerate(unique_labels)}
encoded_labels = np.array([label_map[label] for label in labels])
categorical_labels = to_categorical(encoded_labels)

# Define cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Variables to store all true and predicted labels for confusion matrix and classification report
all_true_labels = []
all_predicted_labels = []

# Variables to store accuracy and loss for plotting each fold
train_accuracies_folds = []
val_accuracies_folds = []
train_losses_folds = []
val_losses_folds = []

# Function to create a BLSTM model
def create_blstm_model(input_shape, num_classes):
    model = Sequential()
    model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(Bidirectional(LSTM(64)))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


# model = Sequential()
#     model.add(Bidirectional(LSTM(256, activation='relu', return_sequences=True), input_shape=(1, X_train.shape[2])))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(128, activation='relu', return_sequences=True)))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(64, activation='relu')))
#     model.add(BatchNormalization())
#     model.add(Dropout(0.3))
#     model.add(Dense(128, activation='relu'))
#     model.add(Dropout(0.3))
#     model.add(Dense(len(np.unique(y)), activation='softmax'))

# Perform 5-fold cross-validation
fold = 1
for train_index, val_index in kf.split(features):
    print(f"Training on fold {fold}...")
    fold += 1
    
    # Split data
    X_train, X_val = features[train_index], features[val_index]
    y_train, y_val = categorical_labels[train_index], categorical_labels[val_index]

    # Get input shape and number of classes
    input_shape = (X_train.shape[1], X_train.shape[2])
    num_classes = categorical_labels.shape[1]

    # Create and compile the model
    model = create_blstm_model(input_shape, num_classes)

    # Early stopping for better training
    #early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Train the model
    history = model.fit(X_train, y_train, 
              epochs=30,  # You can adjust the number of epochs
              batch_size=32, 
              validation_data=(X_val, y_val), 
              #callbacks=[early_stopping], 
              verbose=1)
    
    # Store training and validation accuracy and loss for the fold
    train_accuracies_folds.append(history.history['accuracy'])
    val_accuracies_folds.append(history.history['val_accuracy'])
    train_losses_folds.append(history.history['loss'])
    val_losses_folds.append(history.history['val_loss'])

    # Predict the labels on the validation set
    val_predictions = np.argmax(model.predict(X_val), axis=1)
    true_labels = np.argmax(y_val, axis=1)

    # Store true and predicted labels
    all_true_labels.extend(true_labels)
    all_predicted_labels.extend(val_predictions)

# Plot accuracy and loss plots
epochs = np.arange(1, len(train_accuracies_folds[0]) + 1)

plt.figure(figsize=(12, 5))

# Accuracy plot for each fold
plt.subplot(1, 2, 1)
for i, (train_acc, val_acc) in enumerate(zip(train_accuracies_folds, val_accuracies_folds)):
    plt.plot(epochs, train_acc, label=f'Train Accuracy (Fold {i+1})')
    plt.plot(epochs, val_acc, label=f'Val Accuracy (Fold {i+1})', linestyle='--')

plt.title('Accuracy Plot')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot for each fold
plt.subplot(1, 2, 2)
for i, (train_loss, val_loss) in enumerate(zip(train_losses_folds, val_losses_folds)):
    plt.plot(epochs, train_loss, label=f'Train Loss (Fold {i+1})')
    plt.plot(epochs, val_loss, label=f'Val Loss (Fold {i+1})', linestyle='--')

plt.title('Loss Plot')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 2024-11-13 10:39:24.616061: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Training on fold 1...
# 2024-11-13 10:39:24.649130: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 10:39:24.649314: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 10:39:24.650255: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 10:39:24.650411: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 10:39:24.650548: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 10:39:24.707818: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 10:39:24.708085: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 10:39:24.708271: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 10:39:24.708382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10200 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0b:00.0, compute capability: 6.1
# Epoch 1/30
# 2024-11-13 10:39:27.893554: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1217 - loss: 2.8082 - val_accuracy: 0.4542 - val_loss: 1.8200
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3856 - loss: 1.9146 - val_accuracy: 0.5840 - val_loss: 1.2859
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5426 - loss: 1.3780 - val_accuracy: 0.6222 - val_loss: 1.1449
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6249 - loss: 1.1393 - val_accuracy: 0.6910 - val_loss: 0.9358
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6794 - loss: 0.9640 - val_accuracy: 0.7194 - val_loss: 0.8826
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7360 - loss: 0.8215 - val_accuracy: 0.7257 - val_loss: 0.8449
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7742 - loss: 0.7162 - val_accuracy: 0.7326 - val_loss: 0.8563
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7838 - loss: 0.6529 - val_accuracy: 0.7660 - val_loss: 0.7890
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8102 - loss: 0.5754 - val_accuracy: 0.7576 - val_loss: 0.8004
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8287 - loss: 0.5286 - val_accuracy: 0.7653 - val_loss: 0.8508
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8465 - loss: 0.4875 - val_accuracy: 0.7889 - val_loss: 0.7450
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8552 - loss: 0.4445 - val_accuracy: 0.7750 - val_loss: 0.7427
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8707 - loss: 0.3820 - val_accuracy: 0.7910 - val_loss: 0.7949
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8736 - loss: 0.4033 - val_accuracy: 0.7951 - val_loss: 0.7670
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8837 - loss: 0.3496 - val_accuracy: 0.7806 - val_loss: 0.8124
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8856 - loss: 0.3515 - val_accuracy: 0.7944 - val_loss: 0.8080
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8948 - loss: 0.3419 - val_accuracy: 0.8028 - val_loss: 0.7485
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9019 - loss: 0.3040 - val_accuracy: 0.7917 - val_loss: 0.8608
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9046 - loss: 0.3032 - val_accuracy: 0.8014 - val_loss: 0.7883
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9090 - loss: 0.2955 - val_accuracy: 0.8104 - val_loss: 0.7690
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9213 - loss: 0.2355 - val_accuracy: 0.8056 - val_loss: 0.7938
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9171 - loss: 0.2566 - val_accuracy: 0.7972 - val_loss: 0.9135
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9214 - loss: 0.2575 - val_accuracy: 0.8083 - val_loss: 0.8608
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9244 - loss: 0.2355 - val_accuracy: 0.8035 - val_loss: 0.8480
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9236 - loss: 0.2326 - val_accuracy: 0.8069 - val_loss: 0.8383
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9283 - loss: 0.2210 - val_accuracy: 0.8208 - val_loss: 0.8256
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9342 - loss: 0.2228 - val_accuracy: 0.8160 - val_loss: 0.8549
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9373 - loss: 0.2027 - val_accuracy: 0.8021 - val_loss: 0.9339
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9386 - loss: 0.1951 - val_accuracy: 0.8062 - val_loss: 0.9617
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9412 - loss: 0.2050 - val_accuracy: 0.8118 - val_loss: 0.8995
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 2...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1447 - loss: 2.7874 - val_accuracy: 0.3812 - val_loss: 1.9525
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3877 - loss: 1.9182 - val_accuracy: 0.5354 - val_loss: 1.3722
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5380 - loss: 1.4215 - val_accuracy: 0.6292 - val_loss: 1.0978
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6297 - loss: 1.1129 - val_accuracy: 0.6799 - val_loss: 0.9677
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6868 - loss: 0.9616 - val_accuracy: 0.7097 - val_loss: 0.8864
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7304 - loss: 0.8254 - val_accuracy: 0.7181 - val_loss: 0.8533
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7580 - loss: 0.7414 - val_accuracy: 0.7354 - val_loss: 0.8497
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7926 - loss: 0.6237 - val_accuracy: 0.7507 - val_loss: 0.8076
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8037 - loss: 0.6048 - val_accuracy: 0.7632 - val_loss: 0.8170
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8270 - loss: 0.5265 - val_accuracy: 0.7660 - val_loss: 0.7808
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8378 - loss: 0.4679 - val_accuracy: 0.7743 - val_loss: 0.7755
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8558 - loss: 0.4499 - val_accuracy: 0.7868 - val_loss: 0.7513
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8682 - loss: 0.4035 - val_accuracy: 0.7667 - val_loss: 0.8579
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8683 - loss: 0.3904 - val_accuracy: 0.7833 - val_loss: 0.7665
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8825 - loss: 0.3488 - val_accuracy: 0.7889 - val_loss: 0.8214
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8905 - loss: 0.3405 - val_accuracy: 0.8028 - val_loss: 0.8023
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8956 - loss: 0.3132 - val_accuracy: 0.7979 - val_loss: 0.7967
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8932 - loss: 0.3156 - val_accuracy: 0.7972 - val_loss: 0.8057
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8923 - loss: 0.3155 - val_accuracy: 0.7951 - val_loss: 0.7987
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9098 - loss: 0.2712 - val_accuracy: 0.8049 - val_loss: 0.7578
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9133 - loss: 0.2655 - val_accuracy: 0.7993 - val_loss: 0.8381
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9086 - loss: 0.2784 - val_accuracy: 0.8014 - val_loss: 0.7933
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9205 - loss: 0.2438 - val_accuracy: 0.8188 - val_loss: 0.7718
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9229 - loss: 0.2350 - val_accuracy: 0.8111 - val_loss: 0.8012
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9194 - loss: 0.2593 - val_accuracy: 0.7993 - val_loss: 0.7825
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9231 - loss: 0.2212 - val_accuracy: 0.8104 - val_loss: 0.8037
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9262 - loss: 0.2097 - val_accuracy: 0.8056 - val_loss: 0.8260
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9319 - loss: 0.2033 - val_accuracy: 0.8181 - val_loss: 0.7806
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9365 - loss: 0.1993 - val_accuracy: 0.8188 - val_loss: 0.7952
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9409 - loss: 0.1720 - val_accuracy: 0.8021 - val_loss: 0.8830
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 3...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1180 - loss: 2.8215 - val_accuracy: 0.3646 - val_loss: 2.0489
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3891 - loss: 1.9293 - val_accuracy: 0.5333 - val_loss: 1.4331
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5421 - loss: 1.4200 - val_accuracy: 0.6347 - val_loss: 1.1505
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6420 - loss: 1.1211 - val_accuracy: 0.6771 - val_loss: 1.0571
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6994 - loss: 0.9517 - val_accuracy: 0.7063 - val_loss: 0.9607
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7434 - loss: 0.7817 - val_accuracy: 0.7243 - val_loss: 0.9261
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7641 - loss: 0.7202 - val_accuracy: 0.7306 - val_loss: 0.9137
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7940 - loss: 0.6194 - val_accuracy: 0.7319 - val_loss: 0.9126
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8191 - loss: 0.5618 - val_accuracy: 0.7403 - val_loss: 0.8945
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8337 - loss: 0.4926 - val_accuracy: 0.7569 - val_loss: 0.8439
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8316 - loss: 0.4862 - val_accuracy: 0.7639 - val_loss: 0.8442
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8618 - loss: 0.4149 - val_accuracy: 0.7729 - val_loss: 0.8226
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8593 - loss: 0.4080 - val_accuracy: 0.7660 - val_loss: 0.8399
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8736 - loss: 0.3907 - val_accuracy: 0.7833 - val_loss: 0.8362
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8819 - loss: 0.3427 - val_accuracy: 0.7868 - val_loss: 0.8600
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8909 - loss: 0.3152 - val_accuracy: 0.7729 - val_loss: 0.8927
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8829 - loss: 0.3490 - val_accuracy: 0.7882 - val_loss: 0.8056
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9084 - loss: 0.2819 - val_accuracy: 0.7785 - val_loss: 0.8542
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8978 - loss: 0.2973 - val_accuracy: 0.7826 - val_loss: 0.8618
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9061 - loss: 0.2854 - val_accuracy: 0.7833 - val_loss: 0.9231
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9032 - loss: 0.2962 - val_accuracy: 0.7917 - val_loss: 0.9089
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9220 - loss: 0.2465 - val_accuracy: 0.7854 - val_loss: 0.9156
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9178 - loss: 0.2475 - val_accuracy: 0.7986 - val_loss: 0.9033
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9269 - loss: 0.2265 - val_accuracy: 0.8000 - val_loss: 0.8516
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9308 - loss: 0.2081 - val_accuracy: 0.7937 - val_loss: 0.9483
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9232 - loss: 0.2384 - val_accuracy: 0.7833 - val_loss: 0.9254
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9243 - loss: 0.2260 - val_accuracy: 0.7847 - val_loss: 0.9567
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9253 - loss: 0.2292 - val_accuracy: 0.7847 - val_loss: 0.9960
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9346 - loss: 0.1960 - val_accuracy: 0.8014 - val_loss: 0.9153
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9478 - loss: 0.1621 - val_accuracy: 0.8014 - val_loss: 0.9703
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 4...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1249 - loss: 2.8418 - val_accuracy: 0.3819 - val_loss: 2.0295
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3803 - loss: 1.9792 - val_accuracy: 0.5333 - val_loss: 1.4315
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5405 - loss: 1.4227 - val_accuracy: 0.6271 - val_loss: 1.1186
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6337 - loss: 1.1440 - val_accuracy: 0.6618 - val_loss: 1.0167
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6720 - loss: 1.0007 - val_accuracy: 0.7132 - val_loss: 0.8585
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7319 - loss: 0.8293 - val_accuracy: 0.7118 - val_loss: 0.8677
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7467 - loss: 0.7860 - val_accuracy: 0.7361 - val_loss: 0.7648
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7784 - loss: 0.6707 - val_accuracy: 0.7361 - val_loss: 0.8293
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7956 - loss: 0.6183 - val_accuracy: 0.7597 - val_loss: 0.7577
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8262 - loss: 0.5212 - val_accuracy: 0.7694 - val_loss: 0.7486
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8376 - loss: 0.4978 - val_accuracy: 0.7521 - val_loss: 0.8164
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8370 - loss: 0.4918 - val_accuracy: 0.7597 - val_loss: 0.8341
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8650 - loss: 0.4200 - val_accuracy: 0.7771 - val_loss: 0.7892
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8774 - loss: 0.3806 - val_accuracy: 0.7792 - val_loss: 0.7635
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8772 - loss: 0.3953 - val_accuracy: 0.7785 - val_loss: 0.7534
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8851 - loss: 0.3527 - val_accuracy: 0.7806 - val_loss: 0.7264
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8932 - loss: 0.3265 - val_accuracy: 0.7903 - val_loss: 0.7748
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9112 - loss: 0.2866 - val_accuracy: 0.8049 - val_loss: 0.7164
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8974 - loss: 0.3196 - val_accuracy: 0.8104 - val_loss: 0.7240
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9067 - loss: 0.2912 - val_accuracy: 0.7965 - val_loss: 0.7480
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9107 - loss: 0.2785 - val_accuracy: 0.8097 - val_loss: 0.7661
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9155 - loss: 0.2741 - val_accuracy: 0.7979 - val_loss: 0.8553
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9220 - loss: 0.2457 - val_accuracy: 0.7958 - val_loss: 0.7891
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9190 - loss: 0.2490 - val_accuracy: 0.8083 - val_loss: 0.7610
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9281 - loss: 0.2383 - val_accuracy: 0.7993 - val_loss: 0.8104
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9199 - loss: 0.2581 - val_accuracy: 0.8104 - val_loss: 0.7895
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9325 - loss: 0.2116 - val_accuracy: 0.7910 - val_loss: 0.8638
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9347 - loss: 0.1980 - val_accuracy: 0.8167 - val_loss: 0.7597
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9378 - loss: 0.1945 - val_accuracy: 0.7903 - val_loss: 0.8493
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9441 - loss: 0.1742 - val_accuracy: 0.8056 - val_loss: 0.7965
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 5...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1321 - loss: 2.8043 - val_accuracy: 0.3799 - val_loss: 1.9244
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4002 - loss: 1.9078 - val_accuracy: 0.5444 - val_loss: 1.3403
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5346 - loss: 1.4077 - val_accuracy: 0.6340 - val_loss: 1.0991
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6426 - loss: 1.1025 - val_accuracy: 0.6826 - val_loss: 0.9812
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6865 - loss: 0.9387 - val_accuracy: 0.6931 - val_loss: 0.9572
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7400 - loss: 0.7932 - val_accuracy: 0.7264 - val_loss: 0.8736
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7671 - loss: 0.6951 - val_accuracy: 0.7299 - val_loss: 0.8418
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7922 - loss: 0.6367 - val_accuracy: 0.7451 - val_loss: 0.8166
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8178 - loss: 0.5456 - val_accuracy: 0.7458 - val_loss: 0.8381
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8245 - loss: 0.5144 - val_accuracy: 0.7569 - val_loss: 0.8411
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8467 - loss: 0.4688 - val_accuracy: 0.7646 - val_loss: 0.8283
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8424 - loss: 0.4468 - val_accuracy: 0.7681 - val_loss: 0.8494
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8659 - loss: 0.3894 - val_accuracy: 0.7778 - val_loss: 0.8237
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8657 - loss: 0.3863 - val_accuracy: 0.7729 - val_loss: 0.8102
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8694 - loss: 0.3816 - val_accuracy: 0.7840 - val_loss: 0.7793
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8876 - loss: 0.3514 - val_accuracy: 0.7799 - val_loss: 0.8501
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8832 - loss: 0.3267 - val_accuracy: 0.7854 - val_loss: 0.8405
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9036 - loss: 0.2797 - val_accuracy: 0.7694 - val_loss: 0.9283
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9053 - loss: 0.2800 - val_accuracy: 0.7750 - val_loss: 0.9216
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8989 - loss: 0.2934 - val_accuracy: 0.7903 - val_loss: 0.8994
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9204 - loss: 0.2414 - val_accuracy: 0.7917 - val_loss: 0.8823
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9207 - loss: 0.2291 - val_accuracy: 0.7903 - val_loss: 0.8981
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9183 - loss: 0.2585 - val_accuracy: 0.7924 - val_loss: 0.8424
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9181 - loss: 0.2563 - val_accuracy: 0.8097 - val_loss: 0.8200
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9353 - loss: 0.1922 - val_accuracy: 0.7861 - val_loss: 0.9381
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9330 - loss: 0.1997 - val_accuracy: 0.7736 - val_loss: 0.9555
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9225 - loss: 0.2425 - val_accuracy: 0.7986 - val_loss: 0.8403
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9296 - loss: 0.2188 - val_accuracy: 0.7910 - val_loss: 0.9081
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9399 - loss: 0.1849 - val_accuracy: 0.7979 - val_loss: 0.9629
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9353 - loss: 0.1904 - val_accuracy: 0.8118 - val_loss: 0.8870
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Calculate overall accuracy
accuracy = accuracy_score(all_true_labels, all_predicted_labels)
print(f"Overall Accuracy: {accuracy * 100:.2f}%")

# Generate classification report
class_report = classification_report(all_true_labels, all_predicted_labels, target_names=unique_labels,  digits =4)
print("Classification Report:\n", class_report)

# Generate the confusion matrix
conf_matrix = confusion_matrix(all_true_labels, all_predicted_labels)

# Normalize the confusion matrix by row (true labels)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix as heatmap with annotated percentages
plt.figure(figsize=(15, 10))
plt.imshow(conf_matrix_normalized, cmap='viridis', interpolation='nearest')

# Choose appropriate text color based on background color
threshold = conf_matrix_normalized.max() / 2.

for i in range(conf_matrix_normalized.shape[0]):
    for j in range(conf_matrix_normalized.shape[1]):
        color = "white" if conf_matrix_normalized[i, j] < threshold else "black"
        plt.text(j, i, format(conf_matrix_normalized[i, j], '.2f'), horizontalalignment="center", color=color)

# Custom ticks for confusion matrix
custom_ticks = ['Akh', 'Zi', 'Thre', 'Tsor', 'Paanch', "Sheh", "Sath", "Aeth", "Nav", "Dah",
                "Kah", "Bah", "Truwah", "Czhodah", "Pandah", "Shurah", "Sadah", "Ardah", "Kunvuh", "Vuh"]
plt.xticks(np.arange(20), custom_ticks, rotation=45)
plt.yticks(np.arange(20), custom_ticks)

plt.colorbar()
plt.title('Confusion Matrix (Normalized)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()




plt.tight_layout()
plt.show()
# Out:
# Overall Accuracy: 80.65%
# Classification Report:
#                precision    recall  f1-score   support
#
#         Aeth     0.8035    0.7722    0.7875       360
#          Akh     0.8234    0.8417    0.8324       360
#        Ardah     0.8073    0.8611    0.8333       360
#          Bah     0.8338    0.7944    0.8137       360
#      Czhodah     0.6656    0.5806    0.6202       360
#          Dah     0.7670    0.8139    0.7898       360
#          Kah     0.7470    0.8611    0.8000       360
#       Kunvuh     0.8837    0.8444    0.8636       360
#          Nav     0.8624    0.8528    0.8575       360
#       Paanch     0.8150    0.7833    0.7989       360
#       Pandah     0.8384    0.8500    0.8441       360
#        Sadah     0.6394    0.6944    0.6658       360
#         Sath     0.8517    0.8139    0.8324       360
#         Sheh     0.8338    0.8639    0.8486       360
#       Shurah     0.8667    0.7944    0.8290       360
#         Thre     0.8170    0.8556    0.8358       360
#       Truwah     0.7318    0.8111    0.7694       360
#         Tsor     0.8069    0.7194    0.7606       360
#          Vuh     0.8843    0.8917    0.8880       360
#           Zi     0.8820    0.8306    0.8555       360
#
#     accuracy                         0.8065      7200
#    macro avg     0.8080    0.8065    0.8063      7200
# weighted avg     0.8080    0.8065    0.8063      7200
