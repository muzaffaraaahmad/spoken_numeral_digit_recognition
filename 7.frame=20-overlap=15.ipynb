# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
import seaborn as sns
import librosa
from librosa import display
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.utils import plot_model
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

import random

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)
# Out:
# 2024-11-13 11:32:45.800020: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-13 11:32:46.406982: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Normalized features

# %%
# Define the path to your dataset
path = "/home/muzaffar/Desktop/Research/papers/mono-model-word-spoken/paper-001-final/1-20 data/ORIGINAL-SLOW-1-20"
dataset_path = path

# Initialize lists to hold features and labels
feature_list = []
label_list = []

# Define a function to normalize the mel-spectrogram
def normalize_mel_spectrogram(mel_spec):
    return (mel_spec - np.mean(mel_spec)) / np.std(mel_spec)

# Define the sample rate (fs)
fs = 16000  # Sample rate in Hz

# Define frame size and overlap based on sample rate (in seconds)
frame_size = int(0.020 * fs)  # 25 ms frame size
overlap = int(0.015 * fs)     # 20 ms overlap size

# Update the feature extraction process
for class_folder in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_folder)

    for file in tqdm(os.listdir(class_path)):
        if not file.endswith('.wav'):
            continue

        audio_path = os.path.join(class_path, file)
        audio, sr = librosa.load(path=audio_path, sr=None)

        # Extract the mel-spectrogram features using the frame size and overlap defined above
        mel_spec = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=frame_size, hop_length=overlap, n_mels=42)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
        normalized_mel_spec = normalize_mel_spectrogram(mel_spec_db)

        # Pad or truncate to a fixed size
        fixed_size = 32
        if normalized_mel_spec.shape[1] < fixed_size:
            # Pad with zeros
            pad_width = fixed_size - normalized_mel_spec.shape[1]
            padded_mel_spec = np.pad(normalized_mel_spec, ((0, 0), (0, pad_width)), mode='constant')
        else:
            # Truncate to fixed size
            padded_mel_spec = normalized_mel_spec[:, :fixed_size]

        feature_list.append(padded_mel_spec.T)
        label_list.append(class_folder)

# Convert to NumPy arrays
features = np.array(feature_list)
labels = np.array(label_list)

print("Feature shape:", features.shape)
print("Label shape:", labels.shape)
# Out:
# 100%|██████████| 361/361 [00:01<00:00, 313.33it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1180.07it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1227.91it/s]
# 100%|██████████| 360/360 [00:00<00:00, 1212.26it/s]
# 100%|██████████| 361/361 [00:00<00:00, 986.72it/s]
# 100%|██████████| 361/361 [00:00<00:00, 908.60it/s]
# 100%|██████████| 360/360 [00:00<00:00, 1049.40it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1154.38it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1086.82it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1126.70it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1095.22it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1095.22it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1081.52it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1200.71it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1200.99it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1218.37it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1203.52it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1238.80it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1122.38it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1193.14it/s]
# Feature shape: (7200, 32, 42)
# Label shape: (7200,)

# %%
features[1].shape
# Out:
# (32, 42)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM, Bidirectional, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold

# Assuming 'features' and 'labels' arrays from the previous step
# One-hot encode labels
unique_labels = np.unique(labels)
label_map = {label: idx for idx, label in enumerate(unique_labels)}
encoded_labels = np.array([label_map[label] for label in labels])
categorical_labels = to_categorical(encoded_labels)

# Define cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Variables to store all true and predicted labels for confusion matrix and classification report
all_true_labels = []
all_predicted_labels = []

# Variables to store accuracy and loss for plotting each fold
train_accuracies_folds = []
val_accuracies_folds = []
train_losses_folds = []
val_losses_folds = []

# Function to create a BLSTM model
def create_blstm_model(input_shape, num_classes):
    model = Sequential()
    model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(Bidirectional(LSTM(64)))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


# model = Sequential()
#     model.add(Bidirectional(LSTM(256, activation='relu', return_sequences=True), input_shape=(1, X_train.shape[2])))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(128, activation='relu', return_sequences=True)))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(64, activation='relu')))
#     model.add(BatchNormalization())
#     model.add(Dropout(0.3))
#     model.add(Dense(128, activation='relu'))
#     model.add(Dropout(0.3))
#     model.add(Dense(len(np.unique(y)), activation='softmax'))

# Perform 5-fold cross-validation
fold = 1
for train_index, val_index in kf.split(features):
    print(f"Training on fold {fold}...")
    fold += 1
    
    # Split data
    X_train, X_val = features[train_index], features[val_index]
    y_train, y_val = categorical_labels[train_index], categorical_labels[val_index]

    # Get input shape and number of classes
    input_shape = (X_train.shape[1], X_train.shape[2])
    num_classes = categorical_labels.shape[1]

    # Create and compile the model
    model = create_blstm_model(input_shape, num_classes)

    # Early stopping for better training
    #early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Train the model
    history = model.fit(X_train, y_train, 
              epochs=30,  # You can adjust the number of epochs
              batch_size=32, 
              validation_data=(X_val, y_val), 
              #callbacks=[early_stopping], 
              verbose=1)
    
    # Store training and validation accuracy and loss for the fold
    train_accuracies_folds.append(history.history['accuracy'])
    val_accuracies_folds.append(history.history['val_accuracy'])
    train_losses_folds.append(history.history['loss'])
    val_losses_folds.append(history.history['val_loss'])

    # Predict the labels on the validation set
    val_predictions = np.argmax(model.predict(X_val), axis=1)
    true_labels = np.argmax(y_val, axis=1)

    # Store true and predicted labels
    all_true_labels.extend(true_labels)
    all_predicted_labels.extend(val_predictions)

# Plot accuracy and loss plots
epochs = np.arange(1, len(train_accuracies_folds[0]) + 1)

plt.figure(figsize=(12, 5))

# Accuracy plot for each fold
plt.subplot(1, 2, 1)
for i, (train_acc, val_acc) in enumerate(zip(train_accuracies_folds, val_accuracies_folds)):
    plt.plot(epochs, train_acc, label=f'Train Accuracy (Fold {i+1})')
    plt.plot(epochs, val_acc, label=f'Val Accuracy (Fold {i+1})', linestyle='--')

plt.title('Accuracy Plot')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot for each fold
plt.subplot(1, 2, 2)
for i, (train_loss, val_loss) in enumerate(zip(train_losses_folds, val_losses_folds)):
    plt.plot(epochs, train_loss, label=f'Train Loss (Fold {i+1})')
    plt.plot(epochs, val_loss, label=f'Val Loss (Fold {i+1})', linestyle='--')

plt.title('Loss Plot')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 2024-11-13 11:32:54.174018: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:32:54.208247: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:32:54.208417: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:32:54.209601: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-
# Training on fold 1...
# L355
# 2024-11-13 11:32:54.209739: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:32:54.209859: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:32:54.263848: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:32:54.264023: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:32:54.264168: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:32:54.264272: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10114 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0b:00.0, compute capability: 6.1
# Epoch 1/30
# 2024-11-13 11:32:57.323915: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1198 - loss: 2.8233 - val_accuracy: 0.4243 - val_loss: 1.8749
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3940 - loss: 1.8843 - val_accuracy: 0.5861 - val_loss: 1.3416
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5302 - loss: 1.4853 - val_accuracy: 0.6007 - val_loss: 1.2652
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6179 - loss: 1.2242 - val_accuracy: 0.7069 - val_loss: 0.9516
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6761 - loss: 1.0228 - val_accuracy: 0.7153 - val_loss: 0.9006
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7127 - loss: 0.9140 - val_accuracy: 0.7451 - val_loss: 0.8356
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7493 - loss: 0.8100 - val_accuracy: 0.7403 - val_loss: 0.8714
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7691 - loss: 0.7525 - val_accuracy: 0.7604 - val_loss: 0.7773
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7897 - loss: 0.6614 - val_accuracy: 0.7771 - val_loss: 0.7361
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8187 - loss: 0.5967 - val_accuracy: 0.7778 - val_loss: 0.7270
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8213 - loss: 0.5801 - val_accuracy: 0.8056 - val_loss: 0.7145
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8338 - loss: 0.5340 - val_accuracy: 0.8146 - val_loss: 0.7003
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8468 - loss: 0.5077 - val_accuracy: 0.7757 - val_loss: 0.7852
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8557 - loss: 0.4778 - val_accuracy: 0.8118 - val_loss: 0.6792
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8639 - loss: 0.4297 - val_accuracy: 0.8069 - val_loss: 0.6913
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8598 - loss: 0.4318 - val_accuracy: 0.8229 - val_loss: 0.6587
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8686 - loss: 0.4123 - val_accuracy: 0.7861 - val_loss: 0.7545
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8861 - loss: 0.3740 - val_accuracy: 0.7972 - val_loss: 0.7520
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8978 - loss: 0.3333 - val_accuracy: 0.8125 - val_loss: 0.7100
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8758 - loss: 0.3855 - val_accuracy: 0.8007 - val_loss: 0.7919
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8838 - loss: 0.3710 - val_accuracy: 0.8257 - val_loss: 0.7130
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9034 - loss: 0.3204 - val_accuracy: 0.8201 - val_loss: 0.7318
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9101 - loss: 0.3090 - val_accuracy: 0.8229 - val_loss: 0.7164
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9206 - loss: 0.2625 - val_accuracy: 0.8201 - val_loss: 0.7206
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9013 - loss: 0.3238 - val_accuracy: 0.8306 - val_loss: 0.7145
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9160 - loss: 0.2782 - val_accuracy: 0.8181 - val_loss: 0.7980
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9148 - loss: 0.2595 - val_accuracy: 0.8278 - val_loss: 0.7059
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9176 - loss: 0.2649 - val_accuracy: 0.8285 - val_loss: 0.7508
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9301 - loss: 0.2112 - val_accuracy: 0.8347 - val_loss: 0.7378
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9236 - loss: 0.2350 - val_accuracy: 0.8132 - val_loss: 0.8467
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 2...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1295 - loss: 2.8162 - val_accuracy: 0.4437 - val_loss: 1.6830
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4356 - loss: 1.7727 - val_accuracy: 0.5840 - val_loss: 1.2910
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5585 - loss: 1.3724 - val_accuracy: 0.6382 - val_loss: 1.1613
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6354 - loss: 1.1440 - val_accuracy: 0.6764 - val_loss: 0.9675
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6829 - loss: 1.0082 - val_accuracy: 0.7118 - val_loss: 0.9198
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7197 - loss: 0.8924 - val_accuracy: 0.7368 - val_loss: 0.8319
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7523 - loss: 0.7931 - val_accuracy: 0.7639 - val_loss: 0.7482
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7757 - loss: 0.6942 - val_accuracy: 0.7646 - val_loss: 0.7593
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7925 - loss: 0.6605 - val_accuracy: 0.7757 - val_loss: 0.7512
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8097 - loss: 0.6342 - val_accuracy: 0.7799 - val_loss: 0.7216
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8106 - loss: 0.6119 - val_accuracy: 0.7819 - val_loss: 0.7312
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8363 - loss: 0.5353 - val_accuracy: 0.7896 - val_loss: 0.7056
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8357 - loss: 0.5135 - val_accuracy: 0.7972 - val_loss: 0.6927
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8364 - loss: 0.5088 - val_accuracy: 0.8028 - val_loss: 0.6930
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8603 - loss: 0.4409 - val_accuracy: 0.8146 - val_loss: 0.6450
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8635 - loss: 0.4474 - val_accuracy: 0.8271 - val_loss: 0.6260
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8826 - loss: 0.3829 - val_accuracy: 0.7910 - val_loss: 0.7212
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8704 - loss: 0.4197 - val_accuracy: 0.8083 - val_loss: 0.6911
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8860 - loss: 0.3686 - val_accuracy: 0.8257 - val_loss: 0.6667
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8972 - loss: 0.3299 - val_accuracy: 0.8222 - val_loss: 0.6735
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9067 - loss: 0.3047 - val_accuracy: 0.8167 - val_loss: 0.6738
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9023 - loss: 0.3144 - val_accuracy: 0.8125 - val_loss: 0.6788
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8977 - loss: 0.3029 - val_accuracy: 0.8215 - val_loss: 0.6559
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9033 - loss: 0.2968 - val_accuracy: 0.8097 - val_loss: 0.7201
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9051 - loss: 0.2979 - val_accuracy: 0.8319 - val_loss: 0.6602
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9123 - loss: 0.2764 - val_accuracy: 0.8354 - val_loss: 0.6742
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9163 - loss: 0.2678 - val_accuracy: 0.8146 - val_loss: 0.7674
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9141 - loss: 0.2694 - val_accuracy: 0.8174 - val_loss: 0.7597
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9215 - loss: 0.2843 - val_accuracy: 0.8243 - val_loss: 0.6523
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9271 - loss: 0.2368 - val_accuracy: 0.8278 - val_loss: 0.7361
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 3...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.1341 - loss: 2.8019 - val_accuracy: 0.3847 - val_loss: 1.9377
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4123 - loss: 1.8426 - val_accuracy: 0.5813 - val_loss: 1.3738
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5531 - loss: 1.3905 - val_accuracy: 0.6361 - val_loss: 1.1567
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6298 - loss: 1.1631 - val_accuracy: 0.6639 - val_loss: 1.0469
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6776 - loss: 0.9996 - val_accuracy: 0.6785 - val_loss: 1.0138
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7130 - loss: 0.8874 - val_accuracy: 0.7264 - val_loss: 0.9320
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7427 - loss: 0.8106 - val_accuracy: 0.7368 - val_loss: 0.8649
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7589 - loss: 0.7541 - val_accuracy: 0.7569 - val_loss: 0.8134
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7891 - loss: 0.6657 - val_accuracy: 0.7472 - val_loss: 0.8319
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7948 - loss: 0.6475 - val_accuracy: 0.7764 - val_loss: 0.7557
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8153 - loss: 0.5789 - val_accuracy: 0.7722 - val_loss: 0.7615
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8329 - loss: 0.5332 - val_accuracy: 0.7764 - val_loss: 0.7231
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8429 - loss: 0.5056 - val_accuracy: 0.7896 - val_loss: 0.7632
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8458 - loss: 0.4823 - val_accuracy: 0.7875 - val_loss: 0.7686
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8573 - loss: 0.4315 - val_accuracy: 0.7951 - val_loss: 0.7062
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8579 - loss: 0.4306 - val_accuracy: 0.7993 - val_loss: 0.7069
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8676 - loss: 0.4085 - val_accuracy: 0.7951 - val_loss: 0.7270
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8897 - loss: 0.3517 - val_accuracy: 0.7917 - val_loss: 0.7607
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8870 - loss: 0.3562 - val_accuracy: 0.7833 - val_loss: 0.8020
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8930 - loss: 0.3317 - val_accuracy: 0.7903 - val_loss: 0.7797
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8897 - loss: 0.3387 - val_accuracy: 0.8111 - val_loss: 0.7298
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9051 - loss: 0.3044 - val_accuracy: 0.8021 - val_loss: 0.7608
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9024 - loss: 0.2931 - val_accuracy: 0.8097 - val_loss: 0.7477
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8965 - loss: 0.3254 - val_accuracy: 0.8188 - val_loss: 0.7615
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8984 - loss: 0.3164 - val_accuracy: 0.8278 - val_loss: 0.7201
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9157 - loss: 0.2699 - val_accuracy: 0.8132 - val_loss: 0.7503
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9089 - loss: 0.2839 - val_accuracy: 0.8139 - val_loss: 0.7640
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9192 - loss: 0.2537 - val_accuracy: 0.8201 - val_loss: 0.7222
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9154 - loss: 0.2652 - val_accuracy: 0.8257 - val_loss: 0.7187
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9254 - loss: 0.2319 - val_accuracy: 0.8222 - val_loss: 0.7792
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 4...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1209 - loss: 2.8482 - val_accuracy: 0.4125 - val_loss: 1.9669
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4019 - loss: 1.9402 - val_accuracy: 0.6153 - val_loss: 1.2443
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5572 - loss: 1.4160 - val_accuracy: 0.6771 - val_loss: 0.9991
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6388 - loss: 1.1462 - val_accuracy: 0.7222 - val_loss: 0.8802
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6807 - loss: 1.0113 - val_accuracy: 0.7458 - val_loss: 0.7893
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7281 - loss: 0.8778 - val_accuracy: 0.7375 - val_loss: 0.8351
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7365 - loss: 0.8533 - val_accuracy: 0.7521 - val_loss: 0.7532
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7653 - loss: 0.7663 - val_accuracy: 0.7715 - val_loss: 0.7263
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7889 - loss: 0.7052 - val_accuracy: 0.7819 - val_loss: 0.7009
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8016 - loss: 0.6395 - val_accuracy: 0.7917 - val_loss: 0.6723
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8063 - loss: 0.6105 - val_accuracy: 0.7743 - val_loss: 0.7548
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8157 - loss: 0.5932 - val_accuracy: 0.8125 - val_loss: 0.6181
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8377 - loss: 0.5108 - val_accuracy: 0.8090 - val_loss: 0.6338
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8334 - loss: 0.5291 - val_accuracy: 0.7917 - val_loss: 0.7030
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8514 - loss: 0.4821 - val_accuracy: 0.8201 - val_loss: 0.6075
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8594 - loss: 0.4640 - val_accuracy: 0.8035 - val_loss: 0.6454
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8646 - loss: 0.4300 - val_accuracy: 0.8083 - val_loss: 0.6657
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8740 - loss: 0.4183 - val_accuracy: 0.8174 - val_loss: 0.5785
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8783 - loss: 0.4097 - val_accuracy: 0.8104 - val_loss: 0.6623
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8814 - loss: 0.3795 - val_accuracy: 0.8118 - val_loss: 0.6371
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8868 - loss: 0.3651 - val_accuracy: 0.8014 - val_loss: 0.7411
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8927 - loss: 0.3449 - val_accuracy: 0.8181 - val_loss: 0.6685
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8867 - loss: 0.3474 - val_accuracy: 0.8299 - val_loss: 0.6957
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9037 - loss: 0.2969 - val_accuracy: 0.8160 - val_loss: 0.7217
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9054 - loss: 0.3000 - val_accuracy: 0.8125 - val_loss: 0.7257
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9035 - loss: 0.2913 - val_accuracy: 0.8326 - val_loss: 0.6455
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9048 - loss: 0.2979 - val_accuracy: 0.8007 - val_loss: 0.7355
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9034 - loss: 0.3007 - val_accuracy: 0.8264 - val_loss: 0.6506
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9073 - loss: 0.2913 - val_accuracy: 0.8340 - val_loss: 0.6466
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9171 - loss: 0.2599 - val_accuracy: 0.8250 - val_loss: 0.7148
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 5...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1407 - loss: 2.8107 - val_accuracy: 0.3958 - val_loss: 1.9339
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3993 - loss: 1.8830 - val_accuracy: 0.5708 - val_loss: 1.3557
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5298 - loss: 1.4567 - val_accuracy: 0.6194 - val_loss: 1.1292
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6226 - loss: 1.1725 - val_accuracy: 0.6910 - val_loss: 0.9677
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6922 - loss: 0.9982 - val_accuracy: 0.7007 - val_loss: 0.9515
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7236 - loss: 0.8926 - val_accuracy: 0.7507 - val_loss: 0.8094
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7541 - loss: 0.7981 - val_accuracy: 0.7708 - val_loss: 0.7754
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7820 - loss: 0.7172 - val_accuracy: 0.7569 - val_loss: 0.7930
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7980 - loss: 0.6648 - val_accuracy: 0.7743 - val_loss: 0.7200
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8056 - loss: 0.6158 - val_accuracy: 0.7875 - val_loss: 0.7145
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8251 - loss: 0.5564 - val_accuracy: 0.7875 - val_loss: 0.7055
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8292 - loss: 0.5423 - val_accuracy: 0.7986 - val_loss: 0.6848
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8493 - loss: 0.4818 - val_accuracy: 0.7944 - val_loss: 0.7009
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8559 - loss: 0.4592 - val_accuracy: 0.7993 - val_loss: 0.7417
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8534 - loss: 0.4827 - val_accuracy: 0.8000 - val_loss: 0.7094
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8862 - loss: 0.3848 - val_accuracy: 0.8090 - val_loss: 0.7199
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8754 - loss: 0.4159 - val_accuracy: 0.8097 - val_loss: 0.7166
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8718 - loss: 0.4119 - val_accuracy: 0.8160 - val_loss: 0.6970
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8914 - loss: 0.3519 - val_accuracy: 0.8146 - val_loss: 0.6692
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8836 - loss: 0.3809 - val_accuracy: 0.8062 - val_loss: 0.7137
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8971 - loss: 0.3450 - val_accuracy: 0.8208 - val_loss: 0.6831
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9019 - loss: 0.3117 - val_accuracy: 0.8194 - val_loss: 0.6805
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9010 - loss: 0.3148 - val_accuracy: 0.8174 - val_loss: 0.7045
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8944 - loss: 0.3243 - val_accuracy: 0.8125 - val_loss: 0.6695
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9182 - loss: 0.2859 - val_accuracy: 0.8146 - val_loss: 0.7467
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9059 - loss: 0.2938 - val_accuracy: 0.8250 - val_loss: 0.7132
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9201 - loss: 0.2593 - val_accuracy: 0.8319 - val_loss: 0.7165
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9143 - loss: 0.2734 - val_accuracy: 0.8250 - val_loss: 0.7155
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9144 - loss: 0.2719 - val_accuracy: 0.8340 - val_loss: 0.6980
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9160 - loss: 0.2541 - val_accuracy: 0.8410 - val_loss: 0.6709
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Calculate overall accuracy
accuracy = accuracy_score(all_true_labels, all_predicted_labels)
print(f"Overall Accuracy: {accuracy * 100:.2f}%")

# Generate classification report
class_report = classification_report(all_true_labels, all_predicted_labels, target_names=unique_labels,  digits =4)
print("Classification Report:\n", class_report)

# Generate the confusion matrix
conf_matrix = confusion_matrix(all_true_labels, all_predicted_labels)

# Normalize the confusion matrix by row (true labels)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix as heatmap with annotated percentages
plt.figure(figsize=(15, 10))
plt.imshow(conf_matrix_normalized, cmap='viridis', interpolation='nearest')

# Choose appropriate text color based on background color
threshold = conf_matrix_normalized.max() / 2.

for i in range(conf_matrix_normalized.shape[0]):
    for j in range(conf_matrix_normalized.shape[1]):
        color = "white" if conf_matrix_normalized[i, j] < threshold else "black"
        plt.text(j, i, format(conf_matrix_normalized[i, j], '.2f'), horizontalalignment="center", color=color)

# Custom ticks for confusion matrix
custom_ticks = ['Akh', 'Zi', 'Thre', 'Tsor', 'Paanch', "Sheh", "Sath", "Aeth", "Nav", "Dah",
                "Kah", "Bah", "Truwah", "Czhodah", "Pandah", "Shurah", "Sadah", "Ardah", "Kunvuh", "Vuh"]
plt.xticks(np.arange(20), custom_ticks, rotation=45)
plt.yticks(np.arange(20), custom_ticks)

plt.colorbar()
plt.title('Confusion Matrix (Normalized)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()




plt.tight_layout()
plt.show()
# Out:
# Overall Accuracy: 82.58%
# Classification Report:
#                precision    recall  f1-score   support
#
#         Aeth     0.7618    0.7194    0.7400       360
#          Akh     0.8112    0.8472    0.8288       360
#        Ardah     0.7916    0.8333    0.8119       360
#          Bah     0.8177    0.8722    0.8441       360
#      Czhodah     0.8082    0.8194    0.8138       360
#          Dah     0.7724    0.7917    0.7819       360
#          Kah     0.8267    0.8611    0.8435       360
#       Kunvuh     0.8005    0.8583    0.8284       360
#          Nav     0.8797    0.7722    0.8225       360
#       Paanch     0.7928    0.7972    0.7950       360
#       Pandah     0.7889    0.8306    0.8092       360
#        Sadah     0.8073    0.8028    0.8050       360
#         Sath     0.7842    0.7972    0.7906       360
#         Sheh     0.8237    0.8694    0.8459       360
#       Shurah     0.8778    0.8778    0.8778       360
#         Thre     0.8525    0.8667    0.8595       360
#       Truwah     0.8508    0.8556    0.8532       360
#         Tsor     0.9000    0.8000    0.8471       360
#          Vuh     0.8933    0.8139    0.8517       360
#           Zi     0.9088    0.8306    0.8679       360
#
#     accuracy                         0.8258      7200
#    macro avg     0.8275    0.8258    0.8259      7200
# weighted avg     0.8275    0.8258    0.8259      7200
