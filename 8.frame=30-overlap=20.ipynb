# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
import seaborn as sns
import librosa
from librosa import display
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.utils import plot_model
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

import random

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)
# Out:
# 2024-11-13 11:38:18.901957: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-13 11:38:19.488215: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Normalized features

# %%
# Define the path to your dataset
path = "/home/muzaffar/Desktop/Research/papers/mono-model-word-spoken/paper-001-final/1-20 data/ORIGINAL-SLOW-1-20"
dataset_path = path

# Initialize lists to hold features and labels
feature_list = []
label_list = []

# Define a function to normalize the mel-spectrogram
def normalize_mel_spectrogram(mel_spec):
    return (mel_spec - np.mean(mel_spec)) / np.std(mel_spec)

# Define the sample rate (fs)
fs = 16000  # Sample rate in Hz

# Define frame size and overlap based on sample rate (in seconds)
frame_size = int(0.030 * fs)  # 25 ms frame size
overlap = int(0.020 * fs)     # 20 ms overlap size

# Update the feature extraction process
for class_folder in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_folder)

    for file in tqdm(os.listdir(class_path)):
        if not file.endswith('.wav'):
            continue

        audio_path = os.path.join(class_path, file)
        audio, sr = librosa.load(path=audio_path, sr=None)

        # Extract the mel-spectrogram features using the frame size and overlap defined above
        mel_spec = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=frame_size, hop_length=overlap, n_mels=42)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
        normalized_mel_spec = normalize_mel_spectrogram(mel_spec_db)

        # Pad or truncate to a fixed size
        fixed_size = 32
        if normalized_mel_spec.shape[1] < fixed_size:
            # Pad with zeros
            pad_width = fixed_size - normalized_mel_spec.shape[1]
            padded_mel_spec = np.pad(normalized_mel_spec, ((0, 0), (0, pad_width)), mode='constant')
        else:
            # Truncate to fixed size
            padded_mel_spec = normalized_mel_spec[:, :fixed_size]

        feature_list.append(padded_mel_spec.T)
        label_list.append(class_folder)

# Convert to NumPy arrays
features = np.array(feature_list)
labels = np.array(label_list)

print("Feature shape:", features.shape)
print("Label shape:", labels.shape)
# Out:
# 100%|██████████| 361/361 [00:01<00:00, 336.22it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1090.57it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1173.22it/s]
# 100%|██████████| 360/360 [00:00<00:00, 1200.10it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1166.00it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1087.32it/s]
# 100%|██████████| 360/360 [00:00<00:00, 1172.14it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1059.60it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1116.70it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1182.08it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1102.46it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1170.43it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1156.18it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1216.30it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1213.17it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1201.57it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1204.21it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1185.37it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1187.67it/s]
# 100%|██████████| 361/361 [00:00<00:00, 1180.05it/s]
# Feature shape: (7200, 32, 42)
# Label shape: (7200,)

# %%
features[1].shape
# Out:
# (32, 42)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM, Bidirectional, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold

# Assuming 'features' and 'labels' arrays from the previous step
# One-hot encode labels
unique_labels = np.unique(labels)
label_map = {label: idx for idx, label in enumerate(unique_labels)}
encoded_labels = np.array([label_map[label] for label in labels])
categorical_labels = to_categorical(encoded_labels)

# Define cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Variables to store all true and predicted labels for confusion matrix and classification report
all_true_labels = []
all_predicted_labels = []

# Variables to store accuracy and loss for plotting each fold
train_accuracies_folds = []
val_accuracies_folds = []
train_losses_folds = []
val_losses_folds = []

# Function to create a BLSTM model
def create_blstm_model(input_shape, num_classes):
    model = Sequential()
    model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(Bidirectional(LSTM(64)))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


# model = Sequential()
#     model.add(Bidirectional(LSTM(256, activation='relu', return_sequences=True), input_shape=(1, X_train.shape[2])))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(128, activation='relu', return_sequences=True)))
#     model.add(BatchNormalization())
#     model.add(Bidirectional(LSTM(64, activation='relu')))
#     model.add(BatchNormalization())
#     model.add(Dropout(0.3))
#     model.add(Dense(128, activation='relu'))
#     model.add(Dropout(0.3))
#     model.add(Dense(len(np.unique(y)), activation='softmax'))

# Perform 5-fold cross-validation
fold = 1
for train_index, val_index in kf.split(features):
    print(f"Training on fold {fold}...")
    fold += 1
    
    # Split data
    X_train, X_val = features[train_index], features[val_index]
    y_train, y_val = categorical_labels[train_index], categorical_labels[val_index]

    # Get input shape and number of classes
    input_shape = (X_train.shape[1], X_train.shape[2])
    num_classes = categorical_labels.shape[1]

    # Create and compile the model
    model = create_blstm_model(input_shape, num_classes)

    # Early stopping for better training
    #early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Train the model
    history = model.fit(X_train, y_train, 
              epochs=30,  # You can adjust the number of epochs
              batch_size=32, 
              validation_data=(X_val, y_val), 
              #callbacks=[early_stopping], 
              verbose=1)
    
    # Store training and validation accuracy and loss for the fold
    train_accuracies_folds.append(history.history['accuracy'])
    val_accuracies_folds.append(history.history['val_accuracy'])
    train_losses_folds.append(history.history['loss'])
    val_losses_folds.append(history.history['val_loss'])

    # Predict the labels on the validation set
    val_predictions = np.argmax(model.predict(X_val), axis=1)
    true_labels = np.argmax(y_val, axis=1)

    # Store true and predicted labels
    all_true_labels.extend(true_labels)
    all_predicted_labels.extend(val_predictions)

# Plot accuracy and loss plots
epochs = np.arange(1, len(train_accuracies_folds[0]) + 1)

plt.figure(figsize=(12, 5))

# Accuracy plot for each fold
plt.subplot(1, 2, 1)
for i, (train_acc, val_acc) in enumerate(zip(train_accuracies_folds, val_accuracies_folds)):
    plt.plot(epochs, train_acc, label=f'Train Accuracy (Fold {i+1})')
    plt.plot(epochs, val_acc, label=f'Val Accuracy (Fold {i+1})', linestyle='--')

plt.title('Accuracy Plot')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot for each fold
plt.subplot(1, 2, 2)
for i, (train_loss, val_loss) in enumerate(zip(train_losses_folds, val_losses_folds)):
    plt.plot(epochs, train_loss, label=f'Train Loss (Fold {i+1})')
    plt.plot(epochs, val_loss, label=f'Val Loss (Fold {i+1})', linestyle='--')

plt.title('Loss Plot')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 2024-11-13 11:38:27.003821: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:38:27.048033: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:38:27.048310: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:38:27.049445: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:38:27.049591: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:38:27.049716: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:38:27.114534: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:38:27.114691: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:38:27.114822: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-13 11:38:27.114911: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10203 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0b:00.0, compute capability: 6.1
# Training on fold 1...
# Epoch 1/30
# 2024-11-13 11:38:30.157456: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1178 - loss: 2.8467 - val_accuracy: 0.4333 - val_loss: 1.8469
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4252 - loss: 1.8412 - val_accuracy: 0.5882 - val_loss: 1.2918
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5761 - loss: 1.3430 - val_accuracy: 0.6646 - val_loss: 1.0735
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6529 - loss: 1.0724 - val_accuracy: 0.7368 - val_loss: 0.8611
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7243 - loss: 0.9043 - val_accuracy: 0.7493 - val_loss: 0.7762
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7598 - loss: 0.7884 - val_accuracy: 0.7632 - val_loss: 0.7455
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7881 - loss: 0.6873 - val_accuracy: 0.7882 - val_loss: 0.7201
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8066 - loss: 0.6300 - val_accuracy: 0.7993 - val_loss: 0.6692
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8257 - loss: 0.5652 - val_accuracy: 0.7972 - val_loss: 0.6624
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8322 - loss: 0.5132 - val_accuracy: 0.8014 - val_loss: 0.6827
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8481 - loss: 0.4808 - val_accuracy: 0.8194 - val_loss: 0.6262
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8670 - loss: 0.4234 - val_accuracy: 0.8278 - val_loss: 0.6644
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8665 - loss: 0.4312 - val_accuracy: 0.8444 - val_loss: 0.5779
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8948 - loss: 0.3577 - val_accuracy: 0.8306 - val_loss: 0.6114
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8964 - loss: 0.3331 - val_accuracy: 0.8326 - val_loss: 0.6121
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8958 - loss: 0.3334 - val_accuracy: 0.8257 - val_loss: 0.6455
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9023 - loss: 0.3207 - val_accuracy: 0.8562 - val_loss: 0.5423
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9148 - loss: 0.2709 - val_accuracy: 0.8361 - val_loss: 0.6395
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9147 - loss: 0.2736 - val_accuracy: 0.8653 - val_loss: 0.5720
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9177 - loss: 0.2726 - val_accuracy: 0.8507 - val_loss: 0.5870
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9232 - loss: 0.2642 - val_accuracy: 0.8222 - val_loss: 0.6878
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8830 - loss: 0.3830 - val_accuracy: 0.8472 - val_loss: 0.6035
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9229 - loss: 0.2620 - val_accuracy: 0.8569 - val_loss: 0.5851
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9303 - loss: 0.2060 - val_accuracy: 0.8417 - val_loss: 0.6505
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9343 - loss: 0.2091 - val_accuracy: 0.8556 - val_loss: 0.6006
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9427 - loss: 0.1813 - val_accuracy: 0.8632 - val_loss: 0.5859
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9378 - loss: 0.1938 - val_accuracy: 0.8493 - val_loss: 0.6247
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9346 - loss: 0.2029 - val_accuracy: 0.8632 - val_loss: 0.5934
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9491 - loss: 0.1698 - val_accuracy: 0.8625 - val_loss: 0.6228
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9420 - loss: 0.1788 - val_accuracy: 0.8507 - val_loss: 0.6643
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 2...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1348 - loss: 2.8266 - val_accuracy: 0.4271 - val_loss: 1.7907
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4309 - loss: 1.7859 - val_accuracy: 0.6194 - val_loss: 1.1905
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5737 - loss: 1.3053 - val_accuracy: 0.7049 - val_loss: 0.9516
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6711 - loss: 1.0400 - val_accuracy: 0.7250 - val_loss: 0.8469
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7207 - loss: 0.8975 - val_accuracy: 0.7653 - val_loss: 0.7508
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7506 - loss: 0.7805 - val_accuracy: 0.7819 - val_loss: 0.7249
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7920 - loss: 0.6820 - val_accuracy: 0.8028 - val_loss: 0.6884
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8202 - loss: 0.5946 - val_accuracy: 0.7965 - val_loss: 0.6653
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8376 - loss: 0.5426 - val_accuracy: 0.8097 - val_loss: 0.6456
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8470 - loss: 0.4966 - val_accuracy: 0.8153 - val_loss: 0.6525
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8542 - loss: 0.4631 - val_accuracy: 0.8222 - val_loss: 0.6153
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8536 - loss: 0.4605 - val_accuracy: 0.8368 - val_loss: 0.6036
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8783 - loss: 0.3956 - val_accuracy: 0.8229 - val_loss: 0.6427
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8805 - loss: 0.3861 - val_accuracy: 0.8292 - val_loss: 0.6349
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8883 - loss: 0.3615 - val_accuracy: 0.8403 - val_loss: 0.6140
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8982 - loss: 0.3138 - val_accuracy: 0.8403 - val_loss: 0.6270
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9128 - loss: 0.2926 - val_accuracy: 0.8451 - val_loss: 0.5899
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9090 - loss: 0.2730 - val_accuracy: 0.8354 - val_loss: 0.6414
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9104 - loss: 0.2751 - val_accuracy: 0.8424 - val_loss: 0.6429
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9081 - loss: 0.2821 - val_accuracy: 0.8292 - val_loss: 0.6696
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9171 - loss: 0.2762 - val_accuracy: 0.8528 - val_loss: 0.5977
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9193 - loss: 0.2484 - val_accuracy: 0.8542 - val_loss: 0.5744
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9376 - loss: 0.2086 - val_accuracy: 0.8396 - val_loss: 0.6945
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9129 - loss: 0.2818 - val_accuracy: 0.8542 - val_loss: 0.5807
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9366 - loss: 0.2026 - val_accuracy: 0.8618 - val_loss: 0.5967
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9370 - loss: 0.1996 - val_accuracy: 0.8583 - val_loss: 0.6318
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9311 - loss: 0.2266 - val_accuracy: 0.8556 - val_loss: 0.6326
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9363 - loss: 0.2045 - val_accuracy: 0.8674 - val_loss: 0.6212
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9450 - loss: 0.1605 - val_accuracy: 0.8590 - val_loss: 0.6611
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9387 - loss: 0.2097 - val_accuracy: 0.8375 - val_loss: 0.6898
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 3...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1407 - loss: 2.7939 - val_accuracy: 0.4208 - val_loss: 1.8223
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4259 - loss: 1.7917 - val_accuracy: 0.6000 - val_loss: 1.2653
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5784 - loss: 1.2833 - val_accuracy: 0.6785 - val_loss: 1.0404
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6593 - loss: 1.0505 - val_accuracy: 0.7118 - val_loss: 0.9000
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6993 - loss: 0.9120 - val_accuracy: 0.7174 - val_loss: 0.8577
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7575 - loss: 0.7526 - val_accuracy: 0.7451 - val_loss: 0.8278
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7764 - loss: 0.6956 - val_accuracy: 0.7785 - val_loss: 0.6988
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8081 - loss: 0.6074 - val_accuracy: 0.7833 - val_loss: 0.7109
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8111 - loss: 0.5996 - val_accuracy: 0.7944 - val_loss: 0.7028
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8405 - loss: 0.5085 - val_accuracy: 0.8056 - val_loss: 0.6698
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8366 - loss: 0.5020 - val_accuracy: 0.8174 - val_loss: 0.6367
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8567 - loss: 0.4535 - val_accuracy: 0.8160 - val_loss: 0.6364
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8729 - loss: 0.3900 - val_accuracy: 0.8118 - val_loss: 0.6745
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8721 - loss: 0.3974 - val_accuracy: 0.8361 - val_loss: 0.5959
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8895 - loss: 0.3427 - val_accuracy: 0.8257 - val_loss: 0.6191
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8934 - loss: 0.3356 - val_accuracy: 0.8236 - val_loss: 0.6703
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9052 - loss: 0.3064 - val_accuracy: 0.8333 - val_loss: 0.6136
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9087 - loss: 0.2910 - val_accuracy: 0.8319 - val_loss: 0.6216
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9145 - loss: 0.2732 - val_accuracy: 0.8250 - val_loss: 0.6754
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9177 - loss: 0.2652 - val_accuracy: 0.8375 - val_loss: 0.6451
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9149 - loss: 0.2667 - val_accuracy: 0.8410 - val_loss: 0.6174
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9246 - loss: 0.2513 - val_accuracy: 0.8361 - val_loss: 0.6476
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9272 - loss: 0.2226 - val_accuracy: 0.8382 - val_loss: 0.6783
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9237 - loss: 0.2254 - val_accuracy: 0.8354 - val_loss: 0.6446
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9391 - loss: 0.1918 - val_accuracy: 0.8264 - val_loss: 0.7431
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9304 - loss: 0.2277 - val_accuracy: 0.8500 - val_loss: 0.5581
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9327 - loss: 0.2062 - val_accuracy: 0.8479 - val_loss: 0.6243
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9361 - loss: 0.1970 - val_accuracy: 0.8549 - val_loss: 0.6162
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9457 - loss: 0.1732 - val_accuracy: 0.8583 - val_loss: 0.6006
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9416 - loss: 0.1883 - val_accuracy: 0.8389 - val_loss: 0.7809
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 4...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1187 - loss: 2.8694 - val_accuracy: 0.3938 - val_loss: 2.0273
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3854 - loss: 1.9940 - val_accuracy: 0.6042 - val_loss: 1.3212
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5541 - loss: 1.4250 - val_accuracy: 0.6646 - val_loss: 1.0516
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6460 - loss: 1.0918 - val_accuracy: 0.7340 - val_loss: 0.8594
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6937 - loss: 0.9576 - val_accuracy: 0.7465 - val_loss: 0.7788
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7588 - loss: 0.8044 - val_accuracy: 0.7750 - val_loss: 0.6927
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7653 - loss: 0.7533 - val_accuracy: 0.7903 - val_loss: 0.6544
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7978 - loss: 0.6547 - val_accuracy: 0.8049 - val_loss: 0.6044
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8140 - loss: 0.6013 - val_accuracy: 0.8160 - val_loss: 0.5679
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8208 - loss: 0.5601 - val_accuracy: 0.8215 - val_loss: 0.5479
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8524 - loss: 0.4969 - val_accuracy: 0.8306 - val_loss: 0.5675
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8643 - loss: 0.4498 - val_accuracy: 0.8278 - val_loss: 0.6176
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8604 - loss: 0.4528 - val_accuracy: 0.8389 - val_loss: 0.5493
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8754 - loss: 0.3904 - val_accuracy: 0.8410 - val_loss: 0.5413
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8922 - loss: 0.3655 - val_accuracy: 0.8479 - val_loss: 0.5473
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8868 - loss: 0.3819 - val_accuracy: 0.8410 - val_loss: 0.5325
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8892 - loss: 0.3484 - val_accuracy: 0.8375 - val_loss: 0.5977
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8880 - loss: 0.3654 - val_accuracy: 0.8625 - val_loss: 0.5044
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9000 - loss: 0.3143 - val_accuracy: 0.8458 - val_loss: 0.5485
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9105 - loss: 0.2843 - val_accuracy: 0.8493 - val_loss: 0.5488
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9064 - loss: 0.3090 - val_accuracy: 0.8576 - val_loss: 0.5339
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9149 - loss: 0.2961 - val_accuracy: 0.8646 - val_loss: 0.4770
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9249 - loss: 0.2395 - val_accuracy: 0.8632 - val_loss: 0.5381
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9382 - loss: 0.2122 - val_accuracy: 0.8618 - val_loss: 0.5362
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9251 - loss: 0.2412 - val_accuracy: 0.8597 - val_loss: 0.5208
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9326 - loss: 0.2133 - val_accuracy: 0.8646 - val_loss: 0.5379
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9206 - loss: 0.2487 - val_accuracy: 0.8590 - val_loss: 0.5538
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9338 - loss: 0.2279 - val_accuracy: 0.8632 - val_loss: 0.5503
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9424 - loss: 0.1848 - val_accuracy: 0.8583 - val_loss: 0.5659
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9458 - loss: 0.1801 - val_accuracy: 0.8625 - val_loss: 0.5690
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training on fold 5...
# Epoch 1/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1324 - loss: 2.8327 - val_accuracy: 0.3660 - val_loss: 2.0412
# Epoch 2/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3931 - loss: 1.8638 - val_accuracy: 0.5993 - val_loss: 1.2357
# Epoch 3/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5539 - loss: 1.3313 - val_accuracy: 0.6292 - val_loss: 1.0782
# Epoch 4/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6316 - loss: 1.1032 - val_accuracy: 0.6986 - val_loss: 0.8828
# Epoch 5/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6940 - loss: 0.9187 - val_accuracy: 0.7451 - val_loss: 0.8220
# Epoch 6/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7492 - loss: 0.7720 - val_accuracy: 0.7528 - val_loss: 0.8169
# Epoch 7/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7671 - loss: 0.7076 - val_accuracy: 0.7792 - val_loss: 0.6986
# Epoch 8/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7963 - loss: 0.6271 - val_accuracy: 0.7972 - val_loss: 0.6841
# Epoch 9/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8228 - loss: 0.5702 - val_accuracy: 0.7840 - val_loss: 0.6801
# Epoch 10/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8304 - loss: 0.5344 - val_accuracy: 0.8021 - val_loss: 0.6740
# Epoch 11/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8594 - loss: 0.4570 - val_accuracy: 0.8146 - val_loss: 0.6304
# Epoch 12/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8758 - loss: 0.4127 - val_accuracy: 0.8104 - val_loss: 0.6256
# Epoch 13/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8588 - loss: 0.4351 - val_accuracy: 0.8188 - val_loss: 0.6451
# Epoch 14/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8868 - loss: 0.3823 - val_accuracy: 0.8125 - val_loss: 0.6937
# Epoch 15/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8914 - loss: 0.3717 - val_accuracy: 0.8292 - val_loss: 0.6457
# Epoch 16/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8845 - loss: 0.3632 - val_accuracy: 0.7993 - val_loss: 0.7678
# Epoch 17/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8901 - loss: 0.3566 - val_accuracy: 0.8236 - val_loss: 0.6368
# Epoch 18/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9004 - loss: 0.3216 - val_accuracy: 0.8472 - val_loss: 0.5518
# Epoch 19/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9156 - loss: 0.2773 - val_accuracy: 0.8542 - val_loss: 0.5565
# Epoch 20/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9200 - loss: 0.2644 - val_accuracy: 0.8451 - val_loss: 0.5997
# Epoch 21/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9271 - loss: 0.2276 - val_accuracy: 0.8500 - val_loss: 0.5994
# Epoch 22/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9166 - loss: 0.2833 - val_accuracy: 0.8333 - val_loss: 0.6357
# Epoch 23/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9259 - loss: 0.2501 - val_accuracy: 0.8486 - val_loss: 0.6095
# Epoch 24/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9331 - loss: 0.2271 - val_accuracy: 0.8583 - val_loss: 0.5534
# Epoch 25/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9358 - loss: 0.2068 - val_accuracy: 0.8458 - val_loss: 0.6030
# Epoch 26/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9358 - loss: 0.2065 - val_accuracy: 0.8444 - val_loss: 0.6387
# Epoch 27/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9342 - loss: 0.2141 - val_accuracy: 0.8333 - val_loss: 0.7055
# Epoch 28/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9453 - loss: 0.1921 - val_accuracy: 0.8618 - val_loss: 0.5982
# Epoch 29/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9507 - loss: 0.1626 - val_accuracy: 0.8535 - val_loss: 0.6498
# Epoch 30/30
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9510 - loss: 0.1640 - val_accuracy: 0.8542 - val_loss: 0.6330
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Calculate overall accuracy
accuracy = accuracy_score(all_true_labels, all_predicted_labels)
print(f"Overall Accuracy: {accuracy * 100:.2f}%")

# Generate classification report
class_report = classification_report(all_true_labels, all_predicted_labels, target_names=unique_labels,  digits =4)
print("Classification Report:\n", class_report)

# Generate the confusion matrix
conf_matrix = confusion_matrix(all_true_labels, all_predicted_labels)

# Normalize the confusion matrix by row (true labels)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix as heatmap with annotated percentages
plt.figure(figsize=(15, 10))
plt.imshow(conf_matrix_normalized, cmap='viridis', interpolation='nearest')

# Choose appropriate text color based on background color
threshold = conf_matrix_normalized.max() / 2.

for i in range(conf_matrix_normalized.shape[0]):
    for j in range(conf_matrix_normalized.shape[1]):
        color = "white" if conf_matrix_normalized[i, j] < threshold else "black"
        plt.text(j, i, format(conf_matrix_normalized[i, j], '.2f'), horizontalalignment="center", color=color)

# Custom ticks for confusion matrix
custom_ticks = ['Akh', 'Zi', 'Thre', 'Tsor', 'Paanch', "Sheh", "Sath", "Aeth", "Nav", "Dah",
                "Kah", "Bah", "Truwah", "Czhodah", "Pandah", "Shurah", "Sadah", "Ardah", "Kunvuh", "Vuh"]
plt.xticks(np.arange(20), custom_ticks, rotation=45)
plt.yticks(np.arange(20), custom_ticks)

plt.colorbar()
plt.title('Confusion Matrix (Normalized)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()




plt.tight_layout()
plt.show()
# Out:
# Overall Accuracy: 84.88%
# Classification Report:
#                precision    recall  f1-score   support
#
#         Aeth     0.8129    0.7722    0.7920       360
#          Akh     0.8487    0.8417    0.8452       360
#        Ardah     0.8757    0.8417    0.8584       360
#          Bah     0.8174    0.8333    0.8253       360
#      Czhodah     0.7893    0.8222    0.8054       360
#          Dah     0.7871    0.8111    0.7989       360
#          Kah     0.8141    0.8639    0.8383       360
#       Kunvuh     0.8712    0.8833    0.8772       360
#          Nav     0.8857    0.8611    0.8732       360
#       Paanch     0.8393    0.8417    0.8405       360
#       Pandah     0.8686    0.8444    0.8563       360
#        Sadah     0.8309    0.8056    0.8181       360
#         Sath     0.8293    0.8639    0.8463       360
#         Sheh     0.8678    0.8750    0.8714       360
#       Shurah     0.8840    0.8889    0.8864       360
#         Thre     0.8920    0.8722    0.8820       360
#       Truwah     0.8941    0.8444    0.8686       360
#         Tsor     0.8622    0.8861    0.8740       360
#          Vuh     0.8229    0.8778    0.8495       360
#           Zi     0.8968    0.8444    0.8698       360
#
#     accuracy                         0.8488      7200
#    macro avg     0.8495    0.8488    0.8488      7200
# weighted avg     0.8495    0.8488    0.8488      7200
